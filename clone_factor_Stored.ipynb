# %%
# blank notebook to look at diff clone factors

# %%
label = "18_20"

mba_overlay = allpop_magbin_results[label]["overlay"]["NEO"]
mba_map = allpop_magbin_results[label]["density_maps_downweighted"]["NEO"]
maps = allpop_magbin_results[label]["density_maps_downweighted"]
maps_all = maps["MBA"] + maps["NEO"] + maps["TNO"] + maps["Trojans"]
mba_prob = maps["NEO"] / np.maximum(maps_all, 1e-30)

fig, axes = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

#  raw final cloned visible objects
axes[0].scatter(
    mba_overlay["vlam"],
    mba_overlay["vbeta"],
    s=4, alpha=0.25, color="tab:blue", rasterized=True
)
axes[0].set_title("NEO final cloned visible objects")
axes[0].set_xlim(*xlim); axes[0].set_ylim(*ylim)
axes[0].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[0].set_ylabel(r"$v_\beta$ (deg/day)")

#  raw smoothed MBA density
im1 = axes[1].pcolormesh(
    X0, Y0, np.log10(np.maximum(mba_map, 1e-30)), shading="auto"
)
axes[1].set_title("NEO smoothed density (18_20)(cf: 150)")
axes[1].set_xlim(*xlim); axes[1].set_ylim(*ylim)
axes[1].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[1].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im1, ax=axes[1], label=r"$\log_{10}\langle n_0 \rangle$")

#  MBA probability fraction
im2 = axes[2].pcolormesh(X0, Y0, mba_prob, shading="auto")
axes[2].set_title("NEO probability fraction")
axes[2].set_xlim(*xlim); axes[2].set_ylim(*ylim)
axes[2].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[2].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im2, ax=axes[2], label="probability")

plt.show()

# %%
# cf 200

# %%
label = "18_20"

mba_overlay = allpop_magbin_results[label]["overlay"]["NEO"]
mba_map = allpop_magbin_results[label]["density_maps_downweighted"]["NEO"]
maps = allpop_magbin_results[label]["density_maps_downweighted"]
maps_all = maps["MBA"] + maps["NEO"] + maps["TNO"] + maps["Trojans"]
mba_prob = maps["NEO"] / np.maximum(maps_all, 1e-30)

fig, axes = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

#  raw final cloned visible objects
axes[0].scatter(
    mba_overlay["vlam"],
    mba_overlay["vbeta"],
    s=4, alpha=0.25, color="tab:blue", rasterized=True
)
axes[0].set_title("NEO final cloned visible objects")
axes[0].set_xlim(*xlim); axes[0].set_ylim(*ylim)
axes[0].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[0].set_ylabel(r"$v_\beta$ (deg/day)")

#  raw smoothed MBA density
im1 = axes[1].pcolormesh(
    X0, Y0, np.log10(np.maximum(mba_map, 1e-30)), shading="auto"
)
axes[1].set_title("NEO smoothed density (18_20)(cf: 150)")
axes[1].set_xlim(*xlim); axes[1].set_ylim(*ylim)
axes[1].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[1].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im1, ax=axes[1], label=r"$\log_{10}\langle n_0 \rangle$")

#  MBA probability fraction
im2 = axes[2].pcolormesh(X0, Y0, mba_prob, shading="auto")
axes[2].set_title("NEO probability fraction")
axes[2].set_xlim(*xlim); axes[2].set_ylim(*ylim)
axes[2].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[2].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im2, ax=axes[2], label="probability")

plt.show()

# %%
label = "18_20"   
mask_radius = 0.2 # deg/day nearest-object cutoff

# raw unmasked downweighted density maps
maps_raw = allpop_magbin_results[label]["density_maps_downweighted_raw"]

# nearest-object distance maps for each population
nearest_dist_maps = allpop_magbin_results[label]["nearest_dist_maps"]

# full unmasked denominator
maps_all_raw = (
    maps_raw["MBA"]
    + maps_raw["NEO"]
    + maps_raw["TNO"]
    + maps_raw["Trojans"]
)

fig, axes = plt.subplots(2, 2, figsize=(14, 12), constrained_layout=True)
axes = axes.ravel()

for ax, pop_name in zip(axes, maps_raw.keys()):

    # compute probability using the raw denominator
    frac_map = np.zeros_like(maps_raw[pop_name], dtype=float)

    good = maps_all_raw > 0
    frac_map[good] = maps_raw[pop_name][good] / maps_all_raw[good]

    # only mask this population after probability is computed
    too_far = nearest_dist_maps[pop_name] > mask_radius
    frac_map[too_far] = 0.0

    im = ax.pcolormesh(
        X0, Y0,
        frac_map,
        shading="auto",
        vmin=0,
        vmax=1,
    )

    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)
    ax.set_xlabel(r"$v_\lambda$ (deg/day)")
    ax.set_ylabel(r"$v_\beta$ (deg/day)")
    ax.set_title(f"{pop_name}: cloned/downweighted probability\ncenter=(180,0)")
    fig.colorbar(im, ax=ax, label="probability")

plt.show()

# %%
# cf = 300

# %%
label = "18_20"

mba_overlay = allpop_magbin_results[label]["overlay"]["NEO"]
mba_map = allpop_magbin_results[label]["density_maps_downweighted"]["NEO"]
maps = allpop_magbin_results[label]["density_maps_downweighted"]
maps_all = maps["MBA"] + maps["NEO"] + maps["TNO"] + maps["Trojans"]
mba_prob = maps["NEO"] / np.maximum(maps_all, 1e-30)

fig, axes = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

#  raw final cloned visible objects
axes[0].scatter(
    mba_overlay["vlam"],
    mba_overlay["vbeta"],
    s=4, alpha=0.25, color="tab:blue", rasterized=True
)
axes[0].set_title("NEO final cloned visible objects")
axes[0].set_xlim(*xlim); axes[0].set_ylim(*ylim)
axes[0].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[0].set_ylabel(r"$v_\beta$ (deg/day)")

#  raw smoothed MBA density
im1 = axes[1].pcolormesh(
    X0, Y0, np.log10(np.maximum(mba_map, 1e-30)), shading="auto"
)
axes[1].set_title("NEO smoothed density (18_20)(cf: 150)")
axes[1].set_xlim(*xlim); axes[1].set_ylim(*ylim)
axes[1].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[1].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im1, ax=axes[1], label=r"$\log_{10}\langle n_0 \rangle$")

#  MBA probability fraction
im2 = axes[2].pcolormesh(X0, Y0, mba_prob, shading="auto")
axes[2].set_title("NEO probability fraction")
axes[2].set_xlim(*xlim); axes[2].set_ylim(*ylim)
axes[2].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[2].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im2, ax=axes[2], label="probability")

plt.show()

# %%
label = "18_20"   
mask_radius = 0.2 # deg/day nearest-object cutoff

# raw unmasked downweighted density maps
maps_raw = allpop_magbin_results[label]["density_maps_downweighted_raw"]

# nearest-object distance maps for each population
nearest_dist_maps = allpop_magbin_results[label]["nearest_dist_maps"]

# full unmasked denominator
maps_all_raw = (
    maps_raw["MBA"]
    + maps_raw["NEO"]
    + maps_raw["TNO"]
    + maps_raw["Trojans"]
)

fig, axes = plt.subplots(2, 2, figsize=(14, 12), constrained_layout=True)
axes = axes.ravel()

for ax, pop_name in zip(axes, maps_raw.keys()):

    # compute probability using the raw denominator
    frac_map = np.zeros_like(maps_raw[pop_name], dtype=float)

    good = maps_all_raw > 0
    frac_map[good] = maps_raw[pop_name][good] / maps_all_raw[good]

    # only mask this population after probability is computed
    too_far = nearest_dist_maps[pop_name] > mask_radius
    frac_map[too_far] = 0.0

    im = ax.pcolormesh(
        X0, Y0,
        frac_map,
        shading="auto",
        vmin=0,
        vmax=1,
    )

    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)
    ax.set_xlabel(r"$v_\lambda$ (deg/day)")
    ax.set_ylabel(r"$v_\beta$ (deg/day)")
    ax.set_title(f"{pop_name}: cloned/downweighted probability\ncenter=(180,0)")
    fig.colorbar(im, ax=ax, label="probability")

plt.show()

# %%
# cf = 400

# %%
label = "18_20"

mba_overlay = allpop_magbin_results[label]["overlay"]["NEO"]
mba_map = allpop_magbin_results[label]["density_maps_downweighted"]["NEO"]
maps = allpop_magbin_results[label]["density_maps_downweighted"]
maps_all = maps["MBA"] + maps["NEO"] + maps["TNO"] + maps["Trojans"]
mba_prob = maps["NEO"] / np.maximum(maps_all, 1e-30)

fig, axes = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

#  raw final cloned visible objects
axes[0].scatter(
    mba_overlay["vlam"],
    mba_overlay["vbeta"],
    s=4, alpha=0.25, color="tab:blue", rasterized=True
)
axes[0].set_title("NEO final cloned visible objects")
axes[0].set_xlim(*xlim); axes[0].set_ylim(*ylim)
axes[0].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[0].set_ylabel(r"$v_\beta$ (deg/day)")

#  raw smoothed MBA density
im1 = axes[1].pcolormesh(
    X0, Y0, np.log10(np.maximum(mba_map, 1e-30)), shading="auto"
)
axes[1].set_title("NEO smoothed density (18_20)(cf: 150)")
axes[1].set_xlim(*xlim); axes[1].set_ylim(*ylim)
axes[1].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[1].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im1, ax=axes[1], label=r"$\log_{10}\langle n_0 \rangle$")

#  MBA probability fraction
im2 = axes[2].pcolormesh(X0, Y0, mba_prob, shading="auto")
axes[2].set_title("NEO probability fraction")
axes[2].set_xlim(*xlim); axes[2].set_ylim(*ylim)
axes[2].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[2].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im2, ax=axes[2], label="probability")

plt.show()

# %%
label = "18_20"   
mask_radius = 0.2 # deg/day nearest-object cutoff

# raw unmasked downweighted density maps
maps_raw = allpop_magbin_results[label]["density_maps_downweighted_raw"]

# nearest-object distance maps for each population
nearest_dist_maps = allpop_magbin_results[label]["nearest_dist_maps"]

# full unmasked denominator
maps_all_raw = (
    maps_raw["MBA"]
    + maps_raw["NEO"]
    + maps_raw["TNO"]
    + maps_raw["Trojans"]
)

fig, axes = plt.subplots(2, 2, figsize=(14, 12), constrained_layout=True)
axes = axes.ravel()

for ax, pop_name in zip(axes, maps_raw.keys()):

    # compute probability using the raw denominator
    frac_map = np.zeros_like(maps_raw[pop_name], dtype=float)

    good = maps_all_raw > 0
    frac_map[good] = maps_raw[pop_name][good] / maps_all_raw[good]

    # only mask this population after probability is computed
    too_far = nearest_dist_maps[pop_name] > mask_radius
    frac_map[too_far] = 0.0

    im = ax.pcolormesh(
        X0, Y0,
        frac_map,
        shading="auto",
        vmin=0,
        vmax=1,
    )

    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)
    ax.set_xlabel(r"$v_\lambda$ (deg/day)")
    ax.set_ylabel(r"$v_\beta$ (deg/day)")
    ax.set_title(f"{pop_name}: cloned/downweighted probability\ncenter=(180,0)")
    fig.colorbar(im, ax=ax, label="probability")

plt.show()

# %%
# cf = 500

# %%
label = "18_20"

mba_overlay = allpop_magbin_results[label]["overlay"]["NEO"]
mba_map = allpop_magbin_results[label]["density_maps_downweighted"]["NEO"]
maps = allpop_magbin_results[label]["density_maps_downweighted"]
maps_all = maps["MBA"] + maps["NEO"] + maps["TNO"] + maps["Trojans"]
mba_prob = maps["NEO"] / np.maximum(maps_all, 1e-30)

fig, axes = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

#  raw final cloned visible objects
axes[0].scatter(
    mba_overlay["vlam"],
    mba_overlay["vbeta"],
    s=4, alpha=0.25, color="tab:blue", rasterized=True
)
axes[0].set_title("NEO final cloned visible objects")
axes[0].set_xlim(*xlim); axes[0].set_ylim(*ylim)
axes[0].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[0].set_ylabel(r"$v_\beta$ (deg/day)")

#  raw smoothed MBA density
im1 = axes[1].pcolormesh(
    X0, Y0, np.log10(np.maximum(mba_map, 1e-30)), shading="auto"
)
axes[1].set_title("NEO smoothed density (18_20)(cf: 150)")
axes[1].set_xlim(*xlim); axes[1].set_ylim(*ylim)
axes[1].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[1].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im1, ax=axes[1], label=r"$\log_{10}\langle n_0 \rangle$")

#  MBA probability fraction
im2 = axes[2].pcolormesh(X0, Y0, mba_prob, shading="auto")
axes[2].set_title("NEO probability fraction")
axes[2].set_xlim(*xlim); axes[2].set_ylim(*ylim)
axes[2].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[2].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im2, ax=axes[2], label="probability")

plt.show()

# %%
label = "18_20"   
mask_radius = 0.2 # deg/day nearest-object cutoff

# raw unmasked downweighted density maps
maps_raw = allpop_magbin_results[label]["density_maps_downweighted_raw"]

# nearest-object distance maps for each population
nearest_dist_maps = allpop_magbin_results[label]["nearest_dist_maps"]

# full unmasked denominator
maps_all_raw = (
    maps_raw["MBA"]
    + maps_raw["NEO"]
    + maps_raw["TNO"]
    + maps_raw["Trojans"]
)

fig, axes = plt.subplots(2, 2, figsize=(14, 12), constrained_layout=True)
axes = axes.ravel()

for ax, pop_name in zip(axes, maps_raw.keys()):

    # compute probability using the raw denominator
    frac_map = np.zeros_like(maps_raw[pop_name], dtype=float)

    good = maps_all_raw > 0
    frac_map[good] = maps_raw[pop_name][good] / maps_all_raw[good]

    # only mask this population after probability is computed
    too_far = nearest_dist_maps[pop_name] > mask_radius
    frac_map[too_far] = 0.0

    im = ax.pcolormesh(
        X0, Y0,
        frac_map,
        shading="auto",
        vmin=0,
        vmax=1,
    )

    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)
    ax.set_xlabel(r"$v_\lambda$ (deg/day)")
    ax.set_ylabel(r"$v_\beta$ (deg/day)")
    ax.set_title(f"{pop_name}: cloned/downweighted probability\ncenter=(180,0)")
    fig.colorbar(im, ax=ax, label="probability")

plt.show()

# %%
# cf = 700

# %%
label = "18_20"

mba_overlay = allpop_magbin_results[label]["overlay"]["NEO"]
mba_map = allpop_magbin_results[label]["density_maps_downweighted"]["NEO"]
maps = allpop_magbin_results[label]["density_maps_downweighted"]
maps_all = maps["MBA"] + maps["NEO"] + maps["TNO"] + maps["Trojans"]
mba_prob = maps["NEO"] / np.maximum(maps_all, 1e-30)

fig, axes = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

#  raw final cloned visible objects
axes[0].scatter(
    mba_overlay["vlam"],
    mba_overlay["vbeta"],
    s=4, alpha=0.25, color="tab:blue", rasterized=True
)
axes[0].set_title("NEO final cloned visible objects")
axes[0].set_xlim(*xlim); axes[0].set_ylim(*ylim)
axes[0].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[0].set_ylabel(r"$v_\beta$ (deg/day)")

#  raw smoothed MBA density
im1 = axes[1].pcolormesh(
    X0, Y0, np.log10(np.maximum(mba_map, 1e-30)), shading="auto"
)
axes[1].set_title("NEO smoothed density (18_20)(cf: 150)")
axes[1].set_xlim(*xlim); axes[1].set_ylim(*ylim)
axes[1].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[1].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im1, ax=axes[1], label=r"$\log_{10}\langle n_0 \rangle$")

#  MBA probability fraction
im2 = axes[2].pcolormesh(X0, Y0, mba_prob, shading="auto")
axes[2].set_title("NEO probability fraction")
axes[2].set_xlim(*xlim); axes[2].set_ylim(*ylim)
axes[2].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[2].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im2, ax=axes[2], label="probability")

plt.show()

# %%
label = "18_20"   
mask_radius = 0.2 # deg/day nearest-object cutoff

# raw unmasked downweighted density maps
maps_raw = allpop_magbin_results[label]["density_maps_downweighted_raw"]

# nearest-object distance maps for each population
nearest_dist_maps = allpop_magbin_results[label]["nearest_dist_maps"]

# full unmasked denominator
maps_all_raw = (
    maps_raw["MBA"]
    + maps_raw["NEO"]
    + maps_raw["TNO"]
    + maps_raw["Trojans"]
)

fig, axes = plt.subplots(2, 2, figsize=(14, 12), constrained_layout=True)
axes = axes.ravel()

for ax, pop_name in zip(axes, maps_raw.keys()):

    # compute probability using the raw denominator
    frac_map = np.zeros_like(maps_raw[pop_name], dtype=float)

    good = maps_all_raw > 0
    frac_map[good] = maps_raw[pop_name][good] / maps_all_raw[good]

    # only mask this population after probability is computed
    too_far = nearest_dist_maps[pop_name] > mask_radius
    frac_map[too_far] = 0.0

    im = ax.pcolormesh(
        X0, Y0,
        frac_map,
        shading="auto",
        vmin=0,
        vmax=1,
    )

    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)
    ax.set_xlabel(r"$v_\lambda$ (deg/day)")
    ax.set_ylabel(r"$v_\beta$ (deg/day)")
    ax.set_title(f"{pop_name}: cloned/downweighted probability\ncenter=(180,0)")
    fig.colorbar(im, ax=ax, label="probability")

plt.show()

# %%
# cf = 900

# %%
label = "18_20"

mba_overlay = allpop_magbin_results[label]["overlay"]["NEO"]
mba_map = allpop_magbin_results[label]["density_maps_downweighted"]["NEO"]
maps = allpop_magbin_results[label]["density_maps_downweighted"]
maps_all = maps["MBA"] + maps["NEO"] + maps["TNO"] + maps["Trojans"]
mba_prob = maps["NEO"] / np.maximum(maps_all, 1e-30)

fig, axes = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

#  raw final cloned visible objects
axes[0].scatter(
    mba_overlay["vlam"],
    mba_overlay["vbeta"],
    s=4, alpha=0.25, color="tab:blue", rasterized=True
)
axes[0].set_title("NEO final cloned visible objects")
axes[0].set_xlim(*xlim); axes[0].set_ylim(*ylim)
axes[0].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[0].set_ylabel(r"$v_\beta$ (deg/day)")

#  raw smoothed MBA density
im1 = axes[1].pcolormesh(
    X0, Y0, np.log10(np.maximum(mba_map, 1e-30)), shading="auto"
)
axes[1].set_title("NEO smoothed density (18_20)(cf: 150)")
axes[1].set_xlim(*xlim); axes[1].set_ylim(*ylim)
axes[1].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[1].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im1, ax=axes[1], label=r"$\log_{10}\langle n_0 \rangle$")

#  MBA probability fraction
im2 = axes[2].pcolormesh(X0, Y0, mba_prob, shading="auto")
axes[2].set_title("NEO probability fraction")
axes[2].set_xlim(*xlim); axes[2].set_ylim(*ylim)
axes[2].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[2].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im2, ax=axes[2], label="probability")

plt.show()

# %%
label = "18_20"   
mask_radius = 0.2 # deg/day nearest-object cutoff

# raw unmasked downweighted density maps
maps_raw = allpop_magbin_results[label]["density_maps_downweighted_raw"]

# nearest-object distance maps for each population
nearest_dist_maps = allpop_magbin_results[label]["nearest_dist_maps"]

# full unmasked denominator
maps_all_raw = (
    maps_raw["MBA"]
    + maps_raw["NEO"]
    + maps_raw["TNO"]
    + maps_raw["Trojans"]
)

fig, axes = plt.subplots(2, 2, figsize=(14, 12), constrained_layout=True)
axes = axes.ravel()

for ax, pop_name in zip(axes, maps_raw.keys()):

    # compute probability using the raw denominator
    frac_map = np.zeros_like(maps_raw[pop_name], dtype=float)

    good = maps_all_raw > 0
    frac_map[good] = maps_raw[pop_name][good] / maps_all_raw[good]

    # only mask this population after probability is computed
    too_far = nearest_dist_maps[pop_name] > mask_radius
    frac_map[too_far] = 0.0

    im = ax.pcolormesh(
        X0, Y0,
        frac_map,
        shading="auto",
        vmin=0,
        vmax=1,
    )

    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)
    ax.set_xlabel(r"$v_\lambda$ (deg/day)")
    ax.set_ylabel(r"$v_\beta$ (deg/day)")
    ax.set_title(f"{pop_name}: cloned/downweighted probability\ncenter=(180,0)")
    fig.colorbar(im, ax=ax, label="probability")

plt.show()

# %%
# cf = 1050

# %%
label = "18_20"

mba_overlay = allpop_magbin_results[label]["overlay"]["NEO"]
mba_map = allpop_magbin_results[label]["density_maps_downweighted"]["NEO"]
maps = allpop_magbin_results[label]["density_maps_downweighted"]
maps_all = maps["MBA"] + maps["NEO"] + maps["TNO"] + maps["Trojans"]
mba_prob = maps["NEO"] / np.maximum(maps_all, 1e-30)

fig, axes = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

#  raw final cloned visible objects
axes[0].scatter(
    mba_overlay["vlam"],
    mba_overlay["vbeta"],
    s=4, alpha=0.25, color="tab:blue", rasterized=True
)
axes[0].set_title("NEO final cloned visible objects")
axes[0].set_xlim(*xlim); axes[0].set_ylim(*ylim)
axes[0].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[0].set_ylabel(r"$v_\beta$ (deg/day)")

#  raw smoothed MBA density
im1 = axes[1].pcolormesh(
    X0, Y0, np.log10(np.maximum(mba_map, 1e-30)), shading="auto"
)
axes[1].set_title("NEO smoothed density (18_20)(cf: 150)")
axes[1].set_xlim(*xlim); axes[1].set_ylim(*ylim)
axes[1].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[1].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im1, ax=axes[1], label=r"$\log_{10}\langle n_0 \rangle$")

#  MBA probability fraction
im2 = axes[2].pcolormesh(X0, Y0, mba_prob, shading="auto")
axes[2].set_title("NEO probability fraction")
axes[2].set_xlim(*xlim); axes[2].set_ylim(*ylim)
axes[2].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[2].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im2, ax=axes[2], label="probability")

plt.show()

# %%
label = "18_20"   
mask_radius = 0.2 # deg/day nearest-object cutoff

# raw unmasked downweighted density maps
maps_raw = allpop_magbin_results[label]["density_maps_downweighted_raw"]

# nearest-object distance maps for each population
nearest_dist_maps = allpop_magbin_results[label]["nearest_dist_maps"]

# full unmasked denominator
maps_all_raw = (
    maps_raw["MBA"]
    + maps_raw["NEO"]
    + maps_raw["TNO"]
    + maps_raw["Trojans"]
)

fig, axes = plt.subplots(2, 2, figsize=(14, 12), constrained_layout=True)
axes = axes.ravel()

for ax, pop_name in zip(axes, maps_raw.keys()):

    # compute probability using the raw denominator
    frac_map = np.zeros_like(maps_raw[pop_name], dtype=float)

    good = maps_all_raw > 0
    frac_map[good] = maps_raw[pop_name][good] / maps_all_raw[good]

    # only mask this population after probability is computed
    too_far = nearest_dist_maps[pop_name] > mask_radius
    frac_map[too_far] = 0.0

    im = ax.pcolormesh(
        X0, Y0,
        frac_map,
        shading="auto",
        vmin=0,
        vmax=1,
    )

    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)
    ax.set_xlabel(r"$v_\lambda$ (deg/day)")
    ax.set_ylabel(r"$v_\beta$ (deg/day)")
    ax.set_title(f"{pop_name}: cloned/downweighted probability\ncenter=(180,0)")
    fig.colorbar(im, ax=ax, label="probability")

plt.show()

# %%
# cf = 1600

# %%
label = "18_20"

mba_overlay = allpop_magbin_results[label]["overlay"]["NEO"]
mba_map = allpop_magbin_results[label]["density_maps_downweighted"]["NEO"]
maps = allpop_magbin_results[label]["density_maps_downweighted"]
maps_all = maps["MBA"] + maps["NEO"] + maps["TNO"] + maps["Trojans"]
mba_prob = maps["NEO"] / np.maximum(maps_all, 1e-30)

fig, axes = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

#  raw final cloned visible objects
axes[0].scatter(
    mba_overlay["vlam"],
    mba_overlay["vbeta"],
    s=4, alpha=0.25, color="tab:blue", rasterized=True
)
axes[0].set_title("NEO final cloned visible objects")
axes[0].set_xlim(*xlim); axes[0].set_ylim(*ylim)
axes[0].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[0].set_ylabel(r"$v_\beta$ (deg/day)")

#  raw smoothed MBA density
im1 = axes[1].pcolormesh(
    X0, Y0, np.log10(np.maximum(mba_map, 1e-30)), shading="auto"
)
axes[1].set_title("NEO smoothed density (18_20)(cf: 150)")
axes[1].set_xlim(*xlim); axes[1].set_ylim(*ylim)
axes[1].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[1].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im1, ax=axes[1], label=r"$\log_{10}\langle n_0 \rangle$")

#  MBA probability fraction
im2 = axes[2].pcolormesh(X0, Y0, mba_prob, shading="auto")
axes[2].set_title("NEO probability fraction")
axes[2].set_xlim(*xlim); axes[2].set_ylim(*ylim)
axes[2].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[2].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im2, ax=axes[2], label="probability")

plt.show()

# %%
label = "18_20"   
mask_radius = 0.2 # deg/day nearest-object cutoff

# raw unmasked downweighted density maps
maps_raw = allpop_magbin_results[label]["density_maps_downweighted_raw"]

# nearest-object distance maps for each population
nearest_dist_maps = allpop_magbin_results[label]["nearest_dist_maps"]

# full unmasked denominator
maps_all_raw = (
    maps_raw["MBA"]
    + maps_raw["NEO"]
    + maps_raw["TNO"]
    + maps_raw["Trojans"]
)

fig, axes = plt.subplots(2, 2, figsize=(14, 12), constrained_layout=True)
axes = axes.ravel()

for ax, pop_name in zip(axes, maps_raw.keys()):

    # compute probability using the raw denominator
    frac_map = np.zeros_like(maps_raw[pop_name], dtype=float)

    good = maps_all_raw > 0
    frac_map[good] = maps_raw[pop_name][good] / maps_all_raw[good]

    # only mask this population after probability is computed
    too_far = nearest_dist_maps[pop_name] > mask_radius
    frac_map[too_far] = 0.0

    im = ax.pcolormesh(
        X0, Y0,
        frac_map,
        shading="auto",
        vmin=0,
        vmax=1,
    )

    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)
    ax.set_xlabel(r"$v_\lambda$ (deg/day)")
    ax.set_ylabel(r"$v_\beta$ (deg/day)")
    ax.set_title(f"{pop_name}: cloned/downweighted probability\ncenter=(180,0)")
    fig.colorbar(im, ax=ax, label="probability")

plt.show()

# %%
# cf = 5000

# %%
label = "18_20"

mba_overlay = allpop_magbin_results[label]["overlay"]["NEO"]
mba_map = allpop_magbin_results[label]["density_maps_downweighted"]["NEO"]
maps = allpop_magbin_results[label]["density_maps_downweighted"]
maps_all = maps["MBA"] + maps["NEO"] + maps["TNO"] + maps["Trojans"]
mba_prob = maps["NEO"] / np.maximum(maps_all, 1e-30)

fig, axes = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

#  raw final cloned visible objects
axes[0].scatter(
    mba_overlay["vlam"],
    mba_overlay["vbeta"],
    s=4, alpha=0.25, color="tab:blue", rasterized=True
)
axes[0].set_title("NEO final cloned visible objects")
axes[0].set_xlim(*xlim); axes[0].set_ylim(*ylim)
axes[0].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[0].set_ylabel(r"$v_\beta$ (deg/day)")

#  raw smoothed MBA density
im1 = axes[1].pcolormesh(
    X0, Y0, np.log10(np.maximum(mba_map, 1e-30)), shading="auto"
)
axes[1].set_title("NEO smoothed density (18_20)(cf: 150)")
axes[1].set_xlim(*xlim); axes[1].set_ylim(*ylim)
axes[1].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[1].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im1, ax=axes[1], label=r"$\log_{10}\langle n_0 \rangle$")

#  MBA probability fraction
im2 = axes[2].pcolormesh(X0, Y0, mba_prob, shading="auto")
axes[2].set_title("NEO probability fraction")
axes[2].set_xlim(*xlim); axes[2].set_ylim(*ylim)
axes[2].set_xlabel(r"$v_\lambda$ (deg/day)")
axes[2].set_ylabel(r"$v_\beta$ (deg/day)")
fig.colorbar(im2, ax=axes[2], label="probability")

plt.show()

# %%
label = "18_20"   
mask_radius = 0.2 # deg/day nearest-object cutoff

# raw unmasked downweighted density maps
maps_raw = allpop_magbin_results[label]["density_maps_downweighted_raw"]

# nearest-object distance maps for each population
nearest_dist_maps = allpop_magbin_results[label]["nearest_dist_maps"]

# full unmasked denominator
maps_all_raw = (
    maps_raw["MBA"]
    + maps_raw["NEO"]
    + maps_raw["TNO"]
    + maps_raw["Trojans"]
)

fig, axes = plt.subplots(2, 2, figsize=(14, 12), constrained_layout=True)
axes = axes.ravel()

for ax, pop_name in zip(axes, maps_raw.keys()):

    # compute probability using the raw denominator
    frac_map = np.zeros_like(maps_raw[pop_name], dtype=float)

    good = maps_all_raw > 0
    frac_map[good] = maps_raw[pop_name][good] / maps_all_raw[good]

    # only mask this population after probability is computed
    too_far = nearest_dist_maps[pop_name] > mask_radius
    frac_map[too_far] = 0.0

    im = ax.pcolormesh(
        X0, Y0,
        frac_map,
        shading="auto",
        vmin=0,
        vmax=1,
    )

    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)
    ax.set_xlabel(r"$v_\lambda$ (deg/day)")
    ax.set_ylabel(r"$v_\beta$ (deg/day)")
    ax.set_title(f"{pop_name}: cloned/downweighted probability\ncenter=(180,0)")
    fig.colorbar(im, ax=ax, label="probability")

plt.show()
