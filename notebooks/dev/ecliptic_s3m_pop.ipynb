# %%
import sys
sys.path.insert(0, "../../src")
# notebook for vlam/vbet plots for all populations from s3m
# was made because neoscore.py scorer is too slow for these plots since makeddotgrids has 60 x 120 grids instead of 100 so lengthy.

# %%
## automatically reload 
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import NEOfaster as nf
import NEOMOD3 as nm3
import neoom as no
import S3Marray as sm
import S3M_fullversion as smfull
import neoonlyS3M as neo3m
import trojans as tjn
import tnos as tn
import importlib
from functools import reduce
importlib.reload(nm3)
# Out:
# <module 'NEOMOD3' from '/astro/users/ds2004/digest3/NEOMOD3.py'>

# %%
df, array4D, H_center, a_center, e_center, i_center = nm3.getNEOMOD3orbits()

# %%
obstime_str="2025-09-23T00:00:00"
#ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 186.35, -5.0, 46.27, -19.0
#ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 359.9, -0.07, -0.188316, -0.08016
ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 80.0, 20.0, 0.12, 0.22
# add mag here
mag = 20.0
#mag = 21.563
# anti-Sun at Sep 23 = equinox so RA = 0, Dec = 0
ra0_deg, dec0_deg = 0.0, 0.0

l_hat, v_hat = no.compute_unit_vectors(ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day)
obstime, rE, vE, r_obs = no.get_earth_and_observer(obstime_str)

# %%
# for the values in vlam/vbet plots 
#ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 10.0, 20.0, 0.12, 0.22
l_hat, v_hat = no.compute_unit_vectors(ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day)
obstime, rE, vE, r_obs = no.get_earth_and_observer(obstime_str) 
neo_score, a, e, i= no.compute_neomod3_weight(0.2, 3.0, l_hat, v_hat, obstime, rE, vE, r_obs, array4D, H_center, a_center, e_center, i_center)




print("neo_score:", neo_score)
print("a:", a)
print("e:", e)
print("i:", i)
# Out:
# neo_score: 0.064957
# a: 1.4547289094311036
# e: 0.31736085318504975
# i: 2.1368116120813023

# %%
def comp_sum1():
    
    N_rate = 31           #2 mins 30 sec, for 31 = 4 mins 20 sec so around 50 mins for 101 --> 1 min 40 s for 31
    vlam_min, vlam_max = -0.6, 0.6
    vbet_min, vbet_max = -0.6, 0.6

    vlam_vals  = np.linspace(vlam_min, vlam_max, N_rate)
    vbet_vals = np.linspace(vbet_min, vbet_max, N_rate)
    vlam_deg_day = 0.12
    vbeta_deg_day = 0.22
    

    
    
    K = np.zeros((len(vlam_vals), len(vbet_vals)), dtype=float)
    
    for i,vlam in enumerate(vlam_vals):
        for j,vbet in enumerate(vbet_vals):
            dra, ddec = no.ecliptic_rates_to_radec_rates(ra0_deg, dec0_deg, vlam, vbet)
            w_int = no.weight_marginalized_over_d_and_ddot(array4D=array4D, H_center=H_center, a_center=a_center, e_center=e_center, i_center=i_center,
                                                           ra_deg=ra0_deg, dec_deg=dec0_deg, dra_deg_per_day=dra, ddec_deg_per_day=ddec,obstime_str=obstime_str
                                                           )
            

            K[j, i] = w_int
            #print(w_int, dra, ddec)
        #break
    extent = [vlam_vals[0], vlam_vals[-1], vbet_vals[0], vbet_vals[-1]]
    return K, extent

K, extent= comp_sum1()

# %%
from matplotlib import cm
plt.figure(figsize=(6.0, 6.0))
 
my_viridis = cm.get_cmap("viridis", 1024).with_extremes(under="white")
im = plt.imshow(K, origin="lower", extent=extent, cmap=my_viridis, aspect="equal")


plt.colorbar(label="NEO weight (marginalized over d, ddot)")

plt.axhline(0, color="0.8", lw=1)
plt.axvline(0, color="0.8", lw=1)
plt.xlabel(r"$v_\lambda$ (deg/day)")
plt.ylabel(r"$v_\beta$ (deg/day)")
plt.tight_layout()
plt.show()


print(np.min(K), np.median(K), np.max(K))
# Out:
# /tmp/ipykernel_3165335/2393986843.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   my_viridis = cm.get_cmap("viridis", 1024).with_extremes(under="white")
# 0.41915800000000003 0.495346 4.524813206899998

# %%
neo_s3m = neo3m.define_s3m()
# Out:
# ['S0.s3m']
# The final df is done.

# %%
neo_s3m
# Out:
#               OID FORMAT         q         e          i        node  \
# 0       S0000001a    COM  1.251459  0.382244   9.304721  252.063850
# 1       S0000002a    COM  1.286219  0.662518  18.303865  132.486568
# 2       S0000003a    COM  0.617193  0.645272  10.302493   67.484378
# 3       S0000004a    COM  0.383306  0.856419  16.988463  117.793282
# 4       S0000005a    COM  0.569264  0.772125  22.761089  314.323204
# ...           ...    ...       ...       ...        ...         ...
# 268506  S00019Npa    COM  1.120493  0.719870   7.215564  352.065443
# 268507  S00019Nqa    COM  0.138585  0.904027  42.936671   97.053777
# 268508  S00019Nra    COM  0.183840  0.741100  39.592137  226.887464
# 268509  S00019Nsa    COM  1.005092  0.580448  11.451065  194.025698
# 268510  S00019Nta    COM  0.532959  0.585212  22.194290  180.252081
#
#            argperi           t_p       H      t_0  INDEX  N_PAR  MOID  \
# 0       185.610748  54067.969964  10.315  54466.0      1      6    -1
# 1        80.463153  54670.088589  10.818  54466.0      1      6    -1
# 2       182.131418  54522.349738  11.175  54466.0      1      6    -1
# 3       242.430598  54973.510299  11.452  54466.0      1      6    -1
# 4        73.119299  54075.567352  11.678  54466.0      1      6    -1
# ...            ...           ...     ...      ...    ...    ...   ...
# 268506   22.728064  54356.369662  25.000  54466.0      1      6    -1
# 268507  141.837873  54708.693935  25.000  54466.0      1      6    -1
# 268508   45.405407  54453.982901  25.000  54466.0      1      6    -1
# 268509  170.089706  54067.389305  25.000  54466.0      1      6    -1
# 268510  245.450797  54434.771294  25.000  54466.0      1      6    -1
#
#        COMPCODE         a
# 0          MOPS  2.025814
# 1          MOPS  3.811219
# 2          MOPS  1.739907
# 3          MOPS  2.669612
# 4          MOPS  2.498139
# ...         ...       ...
# 268506     MOPS  3.999912
# 268507     MOPS  1.443995
# 268508     MOPS  0.710082
# 268509     MOPS  2.395632
# 268510     MOPS  1.284896
#
# [268511 rows x 15 columns]

# %%
neo_s3m,array4D, H_center, a_center, e_center, i_center= neo3m.s3m_array(neo_s3m)

# %%
obstime_str="2025-09-23T00:00:00"
#ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 186.35, -5.0, 46.27, -19.0
#ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 359.9, -0.07, -0.188316, -0.08016
ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 80.0, 20.0, 0.12, 0.22
# add mag here
mag = 20.0
#mag = 21.563
# anti-Sun at Sep 23 = equinox so RA = 0, Dec = 0
ra0_deg, dec0_deg = 0.0, 0.0

l_hat, v_hat = nf.compute_unit_vectors(ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day)
obstime, rE, vE, r_obs = nf.get_earth_and_observer(obstime_str)

# %%
# for the values in vlam/vbet plots 
#ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 10.0, 20.0, 0.12, 0.22
l_hat, v_hat = no.compute_unit_vectors(ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day)
obstime, rE, vE, r_obs = no.get_earth_and_observer(obstime_str) 
neo_score, a, e, i= no.compute_neomod3_weight(0.2, 3.0, l_hat, v_hat, obstime, rE, vE, r_obs, array4D, H_center, a_center, e_center, i_center)




print("neo_score:", neo_score)
print("a:", a)
print("e:", e)
print("i:", i)
# Out:
# neo_score: 1.0
# a: 1.4547289094311036
# e: 0.31736085318504975
# i: 2.1368116120813023

# %%
def comp_sum1():
    
    N_rate = 31           #2 mins 30 sec, for 31 = 4 mins 20 sec so around 50 mins for 101 --> 1 min 40 s for 31
    vlam_min, vlam_max = -0.6, 0.6
    vbet_min, vbet_max = -0.6, 0.6

    vlam_vals  = np.linspace(vlam_min, vlam_max, N_rate)
    vbet_vals = np.linspace(vbet_min, vbet_max, N_rate)
    vlam_deg_day = 0.12
    vbeta_deg_day = 0.22
    

    
    
    K = np.zeros((len(vlam_vals), len(vbet_vals)), dtype=float)
    
    for i,vlam in enumerate(vlam_vals):
        for j,vbet in enumerate(vbet_vals):
            dra, ddec = nf.ecliptic_rates_to_radec_rates(ra0_deg, dec0_deg, vlam, vbet)
            w_int = nf.weight_marginalized_over_d_and_ddot(array4D=array4D, H_center=H_center, a_center=a_center, e_center=e_center, i_center=i_center,
                                                           ra_deg=ra0_deg, dec_deg=dec0_deg, dra_deg_per_day=dra, ddec_deg_per_day=ddec,obstime_str=obstime_str
                                                           ,mag=None)
            

            K[j, i] = w_int
            #print(w_int, dra, ddec)
        #break
    extent = [vlam_vals[0], vlam_vals[-1], vbet_vals[0], vbet_vals[-1]]
    return K, extent

K, extent= comp_sum1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 31
#      28     extent = [vlam_vals[0], vlam_vals[-1], vbet_vals[0], vbet_vals[-1]]
#      29     return K, extent
# ---> 31 K, extent= comp_sum1()
#
# Cell In[58], line 20, in comp_sum1()
#      18 for j,vbet in enumerate(vbet_vals):
#      19     dra, ddec = nf.ecliptic_rates_to_radec_rates(ra0_deg, dec0_deg, vlam, vbet)
# ---> 20     w_int = nf.weight_marginalized_over_d_and_ddot(array4D=array4D, H_center=H_center, a_center=a_center, e_center=e_center, i_center=i_center,
#      21                                                    ra_deg=ra0_deg, dec_deg=dec0_deg, dra_deg_per_day=dra, ddec_deg_per_day=ddec,obstime_str=obstime_str
#      22                                                    ,mag=None)
#      25     K[j, i] = w_int
#      26     #print(w_int, dra, ddec)
#      27 #break
#
# File ~/digest3/NEOfaster.py:111, in weight_marginalized_over_d_and_ddot(array4D, H_center, a_center, e_center, i_center, ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day, obstime_str, mag)
#     109 for d_au in d_grid:
#     110     for ddot_kms in ddot_grid:
# --> 111         out = compute_neomod3_weight(d_au, ddot_kms, l_hat, v_hat, mag, obstime,
#     112                        rE, vE, r_tele,
#     113                        array4D, H_center, a_center, e_center, i_center)
#     114         w = out[0] if isinstance(out, tuple) else float(out)
#     115         w_sum += w
#
# File ~/digest3/NEOfaster.py:331, in compute_neomod3_weight(d_au, ddot_kms, l_hat, v_hat, mag, obstime, rE, vE, r_tele, array4D, H_center, a_center, e_center, i_center)
#     325 r_ecl, v_ecl = equatorial_to_ecliptic(r_helio, v_helio)
#     329 a_val, e_val, i_val = to_keplerian_adam(r_ecl, v_ecl, obstime)
# --> 331 H0 = compute_h0_from_distance(r_helio, r_geo, r_tele, d_au, mag)
#     332 #H0 = 19.0
#     333
#     334 #score = score_from_elements_interp(a_val, e_val, 19.0, i_val, interp4D)
#     335 score = score_from_elements(
#     336     a_val, e_val, H0, i_val,
#     337     array4D, H_center, a_center, e_center, i_center
#     338 )
#
# File ~/digest3/NEOfaster.py:303, in compute_h0_from_distance(r_helio, r_geo, r_tele, d_au, mag)
#     300 alpha_deg = np.degrees(alpha_rad)
#     302 # reduced magnitude
# --> 303 H_alpha = mag - 5.0 * np.log10(r_AU * delta_AU)
#     304 # HG phase correction
#     305 A1, A2, B1, B2 = 3.33, 1.87, 0.63, 1.22
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'float'

# %%
from matplotlib import cm
plt.figure(figsize=(6.0, 6.0))
 
my_viridis = cm.get_cmap("viridis", 1024).with_extremes(under="white")
im = plt.imshow(K, origin="lower", extent=extent, cmap=my_viridis, aspect="equal")


plt.colorbar(label="NEO weight (marginalized over d, ddot)")

plt.axhline(0, color="0.8", lw=1)
plt.axvline(0, color="0.8", lw=1)
plt.xlabel(r"$v_\lambda$ (deg/day)")
plt.ylabel(r"$v_\beta$ (deg/day)")
plt.tight_layout()
plt.show()


print(np.min(K), np.median(K), np.max(K))

# %%
### trojans but idk if this is the right way to go abt this

# %%
trojans_s3m = tjn.define_s3m()
# Out:
# ['St5.s3m']
# The final df is done.

# %%
tjn_s3m,array4D_tjn, H_center_tjn, a_center_tjn, e_center_tjn, i_center_tjn = tjn.s3m_array(trojans_s3m)

# %%
obstime_str="2025-09-23T00:00:00"
#ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 186.35, -5.0, 46.27, -19.0
#ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 359.9, -0.07, -0.188316, -0.08016
ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 80.0, 20.0, 0.12, 0.22
# add mag here
mag = 20.0
#mag = 21.563
# anti-Sun at Sep 23 = equinox so RA = 0, Dec = 0
ra0_deg, dec0_deg = 0.0, 0.0

l_hat, v_hat = nf.compute_unit_vectors(ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day)
obstime, rE, vE, r_obs = nf.get_earth_and_observer(obstime_str)

# %%
# for the values in vlam/vbet plots 
#ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 10.0, 20.0, 0.12, 0.22
l_hat, v_hat = no.compute_unit_vectors(ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day)
obstime, rE, vE, r_obs = no.get_earth_and_observer(obstime_str) 
neo_score, a, e, i= no.compute_neomod3_weight(0.2, 3.0, l_hat, v_hat, obstime, rE, vE, r_obs, array4D_tjn, H_center_tjn, a_center_tjn, e_center_tjn, i_center_tjn)




print("neo_score:", neo_score)
print("a:", a)
print("e:", e)
print("i:", i)
# Out:
# neo_score: 0.0
# a: 1.4547289094311036
# e: 0.31736085318504975
# i: 2.1368116120813023

# %%
def comp_sum1():
    
    N_rate = 31           #2 mins 30 sec, for 31 = 4 mins 20 sec so around 50 mins for 101 --> 1 min 40 s for 31
    vlam_min, vlam_max = -0.6, 0.6
    vbet_min, vbet_max = -0.6, 0.6

    vlam_vals  = np.linspace(vlam_min, vlam_max, N_rate)
    vbet_vals = np.linspace(vbet_min, vbet_max, N_rate)
    vlam_deg_day = 0.12
    vbeta_deg_day = 0.22
    

    
    
    K = np.zeros((len(vlam_vals), len(vbet_vals)), dtype=float)
    
    for i,vlam in enumerate(vlam_vals):
        for j,vbet in enumerate(vbet_vals):
            dra, ddec = nf.ecliptic_rates_to_radec_rates(ra0_deg, dec0_deg, vlam, vbet)
            w_int = nf.weight_marginalized_over_d_and_ddot(array4D=array4D_tjn, H_center=H_center_tjn, a_center=a_center_tjn, e_center=e_center_tjn, i_center=i_center_tjn,
                                                           ra_deg=ra0_deg, dec_deg=dec0_deg, dra_deg_per_day=dra, ddec_deg_per_day=ddec,obstime_str=obstime_str
                                                           ,mag=mag)
            

            K[j, i] = w_int
            #print(w_int, dra, ddec)
        #break
    extent = [vlam_vals[0], vlam_vals[-1], vbet_vals[0], vbet_vals[-1]]
    return K, extent

K, extent= comp_sum1()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 31
#      28     extent = [vlam_vals[0], vlam_vals[-1], vbet_vals[0], vbet_vals[-1]]
#      29     return K, extent
# ---> 31 K, extent= comp_sum1()
#
# Cell In[32], line 20, in comp_sum1()
#      18 for j,vbet in enumerate(vbet_vals):
#      19     dra, ddec = nf.ecliptic_rates_to_radec_rates(ra0_deg, dec0_deg, vlam, vbet)
# ---> 20     w_int = nf.weight_marginalized_over_d_and_ddot(array4D=array4D_tjn, H_center=H_center_tjn, a_center=a_center_tjn, e_center=e_center_tjn, i_center=i_center_tjn,
#      21                                                    ra_deg=ra0_deg, dec_deg=dec0_deg, dra_deg_per_day=dra, ddec_deg_per_day=ddec,obstime_str=obstime_str
#      22                                                    ,mag=mag)
#      25     K[j, i] = w_int
#      26     #print(w_int, dra, ddec)
#      27 #break
#
# File ~/digest3/NEOfaster.py:111, in weight_marginalized_over_d_and_ddot(array4D, H_center, a_center, e_center, i_center, ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day, obstime_str, mag)
#     109 for d_au in d_grid:
#     110     for ddot_kms in ddot_grid:
# --> 111         out = compute_neomod3_weight(d_au, ddot_kms, l_hat, v_hat, mag, obstime,
#     112                        rE, vE, r_tele,
#     113                        array4D, H_center, a_center, e_center, i_center)
#     114         w = out[0] if isinstance(out, tuple) else float(out)
#     115         w_sum += w
#
# File ~/digest3/NEOfaster.py:329, in compute_neomod3_weight(d_au, ddot_kms, l_hat, v_hat, mag, obstime, rE, vE, r_tele, array4D, H_center, a_center, e_center, i_center)
#     324 r_helio, v_helio = geo_to_topo(r_geo, v_geo, rE, vE, r_tele, obstime)
#     325 r_ecl, v_ecl = equatorial_to_ecliptic(r_helio, v_helio)
# --> 329 a_val, e_val, i_val = to_keplerian_adam(r_ecl, v_ecl, obstime)
#     331 H0 = compute_h0_from_distance(r_helio, r_geo, r_tele, d_au, mag)
#     332 #H0 = 19.0
#     333
#     334 #score = score_from_elements_interp(a_val, e_val, 19.0, i_val, interp4D)
#
# File ~/digest3/NEOfaster.py:217, in to_keplerian_adam(r_helio, v_helio, obstime)
#     214     r_vec = r_vec[np.newaxis, :]
#     215     v_vec = v_vec[np.newaxis, :]
# --> 217 cartesian_coordinates = CartesianCoordinates.from_kwargs(
#     218 x=r_vec[:, 0] / KM_P_AU,
#     219 y=r_vec[:, 1] / KM_P_AU,
#     220 z=r_vec[:, 2] / KM_P_AU,
#     221 vx=v_vec[:, 0] / KM_P_AU * S_P_DAY,
#     222 vy=v_vec[:, 1] / KM_P_AU * S_P_DAY,
#     223 vz=v_vec[:, 2] / KM_P_AU * S_P_DAY,
#     224 time=Timestamp.from_astropy(obstime),
#     225 origin=Origin.from_kwargs(code=pa.repeat("SUN", len(r_vec))),
#     226 frame="ecliptic" # ecliptic is the other choice
#     227 )
#     229 keplerian_coordinates = cartesian_coordinates.to_keplerian()
#     232 # Might be useful to store them into an orbits object:
#
# File ~/.local/lib/python3.11/site-packages/quivr/tables.py:334, in Table.from_kwargs(cls, validate, permit_nulls, **kwargs)
#     332 pyarrow_table = cls._build_arrow_table(arrays, metadata)
#     333 attrib_kwargs = cls._attribute_kwargs_from_kwargs(kwargs)
# --> 334 return cls.from_pyarrow(
#     335     table=pyarrow_table,
#     336     validate=validate,
#     337     permit_nulls=permit_nulls,
#     338     **attrib_kwargs,
#     339 )
#
# File ~/.local/lib/python3.11/site-packages/quivr/tables.py:216, in Table.from_pyarrow(cls, table, validate, permit_nulls, **kwargs)
#     214 instance = cls(table, **kwargs)
#     215 if validate:
# --> 216     instance.validate()
#     217 return instance
#
# File ~/.local/lib/python3.11/site-packages/quivr/tables.py:997, in Table.validate(self)
#     995 # Validate subtables
#     996 for name in self._quivr_subtables.keys():
# --> 997     getattr(self, name).validate()
#
# File ~/.local/lib/python3.11/site-packages/quivr/columns.py:244, in SubTableColumn.__get__(self, obj, objtype)
#     240 metadata.update(obj._metadata_for_column(self.name))  # type: ignore
#     242 schema = self.schema.with_metadata(metadata)
# --> 244 subtable = pa.Table.from_arrays(array.flatten(), schema=schema)
#     245 # We don't validate the subtable. If the parent table was validated,
#     246 # then the subtable would have been validated as part of that process.
#     247 # If the parent table is intentionally not validated, then we don't
#     248 # want to validate the subtable at this time as it will throw an error
#     249 # when accessing the subtable as a column (e.g. during concatenation).
#     250 return self.table_type.from_pyarrow(subtable, permit_nulls=self.nullable, validate=False)
#
# KeyboardInterrupt:

# %%
from matplotlib import cm
plt.figure(figsize=(6.0, 6.0))
 
my_viridis = cm.get_cmap("viridis", 1024).with_extremes(under="white")
im = plt.imshow(K, origin="lower", extent=extent, cmap=my_viridis, aspect="equal")


plt.colorbar(label="NEOMOD3 weight (marginalized over d, ddot)")

plt.axhline(0, color="0.8", lw=1)
plt.axvline(0, color="0.8", lw=1)
plt.xlabel(r"$v_\lambda$ (deg/day)")
plt.ylabel(r"$v_\beta$ (deg/day)")
plt.tight_layout()
plt.show()


print(np.min(K), np.median(K), np.max(K))
# Out:
# /tmp/ipykernel_3165335/1500458876.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   my_viridis = cm.get_cmap("viridis", 1024).with_extremes(under="white")
# 27.0 36.0 61.0
