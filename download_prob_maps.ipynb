# %%
# notebook 1 to test refactoring .py file -- used to load and save all the probability maps

# %%
## automatically reload 
# %reload_ext autoreload
# %autoreload 2

# %%
import velocity_density_pipeline as vdp

# generate maps once for an obstime — saves all 4 pops × 8 mag bins to one .npz
vdp.generate_probability_maps(
    obstime_str="2025-03-21T00:00:00",
    output_path="prob_maps_2025-03-21.npz",
)
# Out:
# [generate_probability_maps] loading populations...
# [load_all_populations] loading MBA (mba)...
# Search pattern: S1_*.s3m
# Search dirs: ['.', 'S3Mdata']
# Matched files: ['./S1_00.s3m', './S1_01.s3m', './S1_02.s3m', './S1_03.s3m', './S1_04.s3m', './S1_05.s3m', './S1_06.s3m', './S1_07.s3m', './S1_08.s3m', './S1_09.s3m', './S1_10.s3m', './S1_11.s3m', './S1_12.s3m', './S1_13.s3m']
# Loaded 14 file(s).
# Final dataframe shape: (13883361, 15)
# The final df is done.
#   loaded 13883361 objects.
# [load_all_populations] loading NEO (neo)...
# Search pattern: S0.s3m
# Search dirs: ['.', 'S3Mdata']
# Matched files: ['./S0.s3m']
# Loaded 1 file(s).
# Final dataframe shape: (268511, 15)
# The final df is done.
#   loaded 268511 objects.
# [load_all_populations] loading TNO (tno)...
# Search pattern: ST.s3m
# Search dirs: ['.', 'S3Mdata']
# Matched files: ['./ST.s3m']
# Loaded 1 file(s).
# Final dataframe shape: (48682, 15)
# The final df is done.
#   loaded 48682 objects.
# [load_all_populations] loading Trojans (trojan)...
# Search pattern: St5.s3m
# Search dirs: ['.', 'S3Mdata']
# Matched files: ['./St5.s3m']
# Loaded 1 file(s).
# Final dataframe shape: (179882, 15)
# The final df is done.
#   loaded 179882 objects.
#
# ================================================================================
# Running all populations for mag bin: 14_16
#
# [lon180_lat0] MBA with mag cut 14.0 to 16.0...
# Propagate with newton: 100%|██████████| 139/139 [00:10<00:00, 13.88it/s]
#   objects passing mag cut: 1256
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 750.32it/s]
#   visible for conditional cloner: 317
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 63.01it/s]
#   final cloned visible points: 25710
#   building density map with k_eff = 5 (n_visible = 25710)
# Evaluating density map: 100%|██████████| 25921/25921 [02:20<00:00, 184.89it/s]
# MBA done.
#   raw cloned max density   : 18131338.30387621
#   downweighted max density : 181313.3830387621
#
# [lon180_lat0] NEO with mag cut 14.0 to 16.0...
# Propagate with newton: 100%|██████████| 3/3 [00:00<00:00, 20.27it/s]
#   objects passing mag cut: 19
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 3130.08it/s]
#   visible for conditional cloner: 0
#
# [lon180_lat0] TNO with mag cut 14.0 to 16.0...
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 36.97it/s]
#   objects passing mag cut: 0
#
# [lon180_lat0] Trojans with mag cut 14.0 to 16.0...
# Propagate with newton: 100%|██████████| 2/2 [00:00<00:00, 18.19it/s]
#   objects passing mag cut: 22
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 4495.50it/s]
#   visible for conditional cloner:
#  5
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 2471.60it/s]
#   final cloned visible points: 152
#   building density map with k_eff = 5 (n_visible = 152)
# Evaluating density map: 100%|██████████| 25921/25921 [02:19<00:00, 186.34it/s]
# Trojans done.
#   raw cloned max density   : 352194.69064107176
#   downweighted max density : 3521.9469064107175
#
# ================================================================================
# Running all populations for mag bin: 16_18
#
# [lon180_lat0] MBA with mag cut 16.0 to 18.0...
# Propagate with newton: 100%|██████████| 139/139 [00:08<00:00, 15.65it/s]
#   objects passing mag cut: 10357
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 158.17it/s]
#   visible for conditional cloner: 3224
# Propagate with newton: 100%|██████████| 4/4 [00:00<00:00, 23.03it/s]
#   final cloned visible points: 262039
#   building density map with k_eff = 5 (n_visible = 262039)
# Evaluating density map: 100%|██████████| 25921/25921 [02:29<00:00, 173.44it/s]
# MBA done.
#   raw cloned max density   : 57993168.86853691
#   downweighted max density : 579931.6886853691
#
# [lon180_lat0] NEO with mag cut 16.0 to 18.0...
# Propagate with newton: 100%|██████████| 3/3 [00:00<00:00, 21.30it/s]
#   objects passing mag cut: 97
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 4048.56it/s]
#   visible for conditional cloner: 8
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 854.59it/s]
#   final cloned visible points: 673
#   building density map with k_eff = 5 (n_visible = 673)
# Evaluating density map: 100%|██████████| 25921/25921 [02:20<00:00, 184.21it/s]
# NEO done.
#   raw cloned max density   : 818680.8193894249
#   downweighted max density : 2728.9360646314162
#
# [lon180_lat0] TNO with mag cut 16.0 to 18.0...
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 30.53it/s]
#   objects passing mag cut: 4
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 5256.02it/s]
#   visible for conditional cloner: 0
#
# [lon180_lat0] Trojans with mag cut 16.0 to 18.0...
# Propagate with newton: 100%|██████████| 2/2 [00:00<00:00, 19.68it/s]
#   objects passing mag cut: 162
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 3326.17it/s]
#   visible for conditional cloner: 36
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 544.29it/s]
#   final cloned visible points: 2925
#   building density map with k_eff = 5 (n_visible = 2925)
# Evaluating density map: 100%|██████████| 25921/25921 [02:21<00:00, 183.79it/s]
# Trojans done.
#   raw cloned max density   : 15564987.021508753
#   downweighted max density : 155649.87021508755
#
# ================================================================================
# Running all populations for mag bin: 18_20
#
# [lon180_lat0] MBA with mag cut 18.0 to 20.0...
# Propagate with newton: 100%|██████████| 139/139 [00:08<00:00, 16.00it/s]
#   objects passing mag cut: 89413
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 21.14it/s]
#   visible for conditional cloner: 22562
# Propagate with newton: 100%|██████████| 23/23 [00:01<00:00, 19.86it/s]
#   final cloned visible points: 1816308
#   building density map with k_eff = 5 (n_visible = 1816308)
# Evaluating density map: 100%|██████████| 25921/25921 [02:22<00:00, 181.47it/s]
# MBA done.
#   raw cloned max density   : 583603012.2524968
#   downweighted max density : 5836030.122524968
#
# [lon180_lat0] NEO with mag cut 18.0 to 20.0...
# Propagate with newton: 100%|██████████| 3/3 [00:00<00:00, 21.06it/s]
#   objects passing mag cut: 417
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 2032.12it/s]
#   visible for conditional cloner: 25
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 260.52it/s]
#   final cloned visible points: 2980
#   building density map with k_eff = 5 (n_visible = 2980)
# Evaluating density map: 100%|██████████| 25921/25921 [02:20<00:00, 184.17it/s]
# NEO done.
#   raw cloned max density   : 1652820.750752187
#   downweighted max density : 5509.402502507291
#
# [lon180_lat0] TNO with mag cut 18.0 to 20.0...
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 38.18it/s]
#   objects passing mag cut: 60
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 2700.78it/s]
#   visible for conditional cloner: 10
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 990.39it/s]
#   final cloned visible points: 814
#   building density map with k_eff = 5 (n_visible = 814)
# Evaluating density map: 100%|██████████| 25921/25921 [02:18<00:00, 187.78it/s]
# TNO done.
#   raw cloned max density   : 1567892590.4403355
#   downweighted max density : 15678925.904403355
#
# [lon180_lat0] Trojans with mag cut 18.0 to 20.0...
# Propagate with newton: 100%|██████████| 2/2 [00:00<00:00, 22.10it/s]
#   objects passing mag cut: 1230
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 1026.76it/s]
#   visible for conditional cloner: 221
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 87.01it/s]
#   final cloned visible points: 17182
#   building density map with k_eff = 5 (n_visible = 17182)
# Evaluating density map: 100%|██████████| 25921/25921 [02:17<00:00, 189.15it/s]
# Trojans done.
#   raw cloned max density   : 28204016.478371367
#   downweighted max density : 282040.16478371364
#
# ================================================================================
# Running all populations for mag bin: mag20
#
# [lon180_lat0] MBA with mag cut 20.0 to 21.0...
# Propagate with newton: 100%|██████████| 139/139 [00:07<00:00, 18.97it/s]
#   objects passing mag cut: 150196
# Propagate with newton: 100%|██████████| 2/2 [00:00<00:00, 26.41it/s]
#   visible for conditional cloner: 31723
# Propagate with newton: 100%|██████████| 32/32 [00:01<00:00, 20.19it/s]
#   final cloned visible points: 2562116
#   building density map with k_eff = 5 (n_visible = 2562116)
# Evaluating density map: 100%|██████████| 25921/25921 [02:18<00:00, 187.34it/s]
# MBA done.
#   raw cloned max density   : 1483150464.425698
#   downweighted max density : 14831504.644256981
#
# [lon180_lat0] NEO with mag cut 20.0 to 21.0...
# Propagate with newton: 100%|██████████| 3/3 [00:00<00:00, 21.65it/s]
#   objects passing mag cut: 627
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 1964.55it/s]
#   visible for conditional cloner: 45
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 131.59it/s]
#   final cloned visible points: 5105
#   building density map with k_eff = 5 (n_visible = 5105)
# Evaluating density map: 100%|██████████| 25921/25921 [02:15<00:00, 190.62it/s]
# NEO done.
#   raw cloned max density   : 5773672.061117776
#   downweighted max density : 19245.573537059252
#
# [lon180_lat0] TNO with mag cut 20.0 to 21.0...
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 37.29it/s]
#   objects passing mag cut: 238
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 3037.15it/s]
#   visible for conditional cloner: 45
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 464.54it/s]
#   final cloned visible points: 3977
#   building density map with k_eff = 5 (n_visible = 3977)
# Evaluating density map: 100%|██████████| 25921/25921 [02:13<00:00, 194.61it/s]
# TNO done.
#   raw cloned max density   : 374679722.2240146
#   downweighted max density : 3746797.222240146
#
# [lon180_lat0] Trojans with mag cut 20.0 to 21.0...
# Propagate with newton: 100%|██████████| 2/2 [00:00<00:00, 17.51it/s]
#   objects passing mag cut: 2540
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 844.94it/s]
#   visible for conditional cloner: 498
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 46.73it/s]
#   final cloned visible points: 39609
#   building density map with k_eff = 5 (n_visible = 39609)
# Evaluating density map: 100%|██████████| 25921/25921 [02:12<00:00, 195.76it/s]
# Trojans done.
#   raw cloned max density   : 73635386.86248064
#   downweighted max density : 736353.8686248064
#
# ================================================================================
# Running all populations for mag bin: mag21
#
# [lon180_lat0] MBA with mag cut 21.0 to 22.0...
# Propagate with newton: 100%|██████████| 139/139 [00:06<00:00, 20.42it/s]
#   objects passing mag cut: 306371
# Propagate with newton: 100%|██████████| 4/4 [00:00<00:00, 27.08it/s]
#   visible for conditional cloner: 59109
# Propagate with newton: 100%|██████████| 60/60 [00:02<00:00, 20.64it/s]
#   final cloned visible points: 4781803
#   building density map with k_eff = 5 (n_visible = 4781803)
# Evaluating density map: 100%|██████████| 25921/25921 [02:11<00:00, 197.25it/s]
# MBA done.
#   raw cloned max density   : 1628914242.09722
#   downweighted max density : 16289142.4209722
#
# [lon180_lat0] NEO with mag cut 21.0 to 22.0...
# Propagate with newton: 100%|██████████| 3/3 [00:00<00:00, 22.06it/s]
#   objects passing mag cut: 1395
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 1117.59it/s]
#   visible for conditional cloner: 115
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 65.19it/s]
#   final cloned visible points: 11618
#   building density map with k_eff = 5 (n_visible = 11618)
# Evaluating density map: 100%|██████████| 25921/25921 [02:11<00:00, 196.85it/s]
# NEO done.
#   raw cloned max density   : 6536975.764997651
#   downweighted max density : 21789.919216658836
#
# [lon180_lat0] TNO with mag cut 21.0 to 22.0...
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 25.12it/s]
#   objects passing mag cut: 1259
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 1043.10it/s]
#   visible for conditional cloner: 209
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 107.96it/s]
#   final cloned visible points: 18923
#   building density map with k_eff = 5 (n_visible = 18923)
# Evaluating density map: 100%|██████████| 25921/25921 [02:11<00:00, 196.44it/s]
# TNO done.
#   raw cloned max density   : 5980219613.868486
#   downweighted max density : 59802196.13868486
#
# [lon180_lat0] Trojans with mag cut 21.0 to 22.0...
# Propagate with newton: 100%|██████████| 2/2 [00:00<00:00, 22.86it/s]
#   objects passing mag cut: 6949
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 237.02it/s]
#   visible for conditional cloner: 1374
# Propagate with newton: 100%|██████████| 2/2 [00:00<00:00, 40.37it/s]
#   final cloned visible points: 107148
#   building density map with k_eff = 5 (n_visible = 107148)
# Evaluating density map: 100%|██████████| 25921/25921 [02:12<00:00, 196.13it/s]
# Trojans done.
#   raw cloned max density   : 137132307.08801746
#   downweighted max density : 1371323.0708801746
#
# ================================================================================
# Running all populations for mag bin: mag22
#
# [lon180_lat0] MBA with mag cut 22.0 to 23.0...
# Propagate with newton: 100%|██████████| 139/139 [00:06<00:00, 20.20it/s]
#   objects passing mag cut: 568946
# Propagate with newton: 100%|██████████| 6/6 [00:00<00:00, 17.05it/s]
#   visible for conditional cloner: 104356
# Propagate with newton: 100%|██████████| 105/105 [00:09<00:00, 11.22it/s]
#   final cloned visible points: 8437802
#   building density map with k_eff = 5 (n_visible = 8437802)
# Evaluating density map: 100%|██████████| 25921/25921 [02:11<00:00, 196.61it/s]
# MBA done.
#   raw cloned max density   : 2893531651.953744
#   downweighted max density : 28935316.519537438
#
# [lon180_lat0] NEO with mag cut 22.0 to 23.0...
# Propagate with newton: 100%|██████████| 3/3 [00:00<00:00, 20.77it/s]
#   objects passing mag cut: 3023
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 592.33it/s]
#   visible for conditional cloner: 212
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 27.16it/s]
#   final cloned visible points: 22024
#   building density map with k_eff = 5 (n_visible = 22024)
# Evaluating density map: 100%|██████████| 25921/25921 [02:12<00:00, 195.68it/s]
# NEO done.
#   raw cloned max density   : 4538137.549681759
#   downweighted max density : 15127.125165605865
#
# [lon180_lat0] TNO with mag cut 22.0 to 23.0...
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 30.94it/s]
#   objects passing mag cut: 5131
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 385.51it/s]
#   visible for conditional cloner: 999
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 19.88it/s]
#   final cloned visible points: 88101
#   building density map with k_eff = 5 (n_visible = 88101)
# Evaluating density map: 100%|██████████| 25921/25921 [02:11<00:00, 196.51it/s]
# TNO done.
#   raw cloned max density   : 8702808998.190775
#   downweighted max density : 87028089.98190776
#
# [lon180_lat0] Trojans with mag cut 22.0 to 23.0...
# Propagate with newton: 100%|██████████| 2/2 [00:00<00:00, 23.15it/s]
#   objects passing mag cut: 20268
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 103.60it/s]
#   visible for conditional cloner: 4147
# Propagate with newton: 100%|██████████| 5/5 [00:00<00:00, 27.93it/s]
#   final cloned visible points: 331471
#   building density map with k_eff = 5 (n_visible = 331471)
# Evaluating density map: 100%|██████████| 25921/25921 [02:12<00:00, 195.30it/s]
# Trojans done.
#   raw cloned max density   : 549769650.7132655
#   downweighted max density : 5497696.507132655
#
# ================================================================================
# Running all populations for mag bin: mag23
#
# [lon180_lat0] MBA with mag cut 23.0 to 24.0...
# Propagate with newton: 100%|██████████| 139/139 [00:12<00:00, 10.70it/s]
#   objects passing mag cut: 1011322
# Propagate with newton: 100%|██████████| 11/11 [00:00<00:00, 22.46it/s]
#   visible for conditional cloner: 184185
# Propagate with newton: 100%|██████████| 185/185 [00:38<00:00,  4.82it/s]
#   final cloned visible points: 14899463
#   building density map with k_eff = 5 (n_visible = 14899463)
# Evaluating density map: 100%|██████████| 25921/25921 [02:11<00:00, 197.54it/s]
# MBA done.
#   raw cloned max density   : 5594467295.9514065
#   downweighted max density : 55944672.95951407
#
# [lon180_lat0] NEO with mag cut 23.0 to 24.0...
# Propagate with newton: 100%|██████████| 3/3 [00:00<00:00, 20.53it/s]
#   objects passing mag cut: 6334
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 184.78it/s]
#   visible for conditional cloner: 387
# Propagate with newton: 100%|██████████| 2/2 [00:00<00:00, 30.26it/s]
#   final cloned visible points: 45727
#   building density map with k_eff = 5 (n_visible = 45727)
# Evaluating density map: 100%|██████████| 25921/25921 [02:11<00:00, 197.13it/s]
# NEO done.
#   raw cloned max density   : 8415594.474905929
#   downweighted max density : 28051.981583019762
#
# [lon180_lat0] TNO with mag cut 23.0 to 24.0...
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 32.06it/s]
#   objects passing mag cut: 16083
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 104.13it/s]
#   visible for conditional cloner: 2718
# Propagate with newton: 100%|██████████| 3/3 [00:00<00:00, 22.08it/s]
#   final cloned visible points: 242075
#   building density map with k_eff = 5 (n_visible = 242075)
# Evaluating density map: 100%|██████████| 25921/25921 [02:11<00:00, 197.12it/s]
# TNO done.
#   raw cloned max density   : 20003778119.175434
#   downweighted max density : 200037781.19175434
#
# [lon180_lat0] Trojans with mag cut 23.0 to 24.0...
# Propagate with newton: 100%|██████████| 2/2 [00:00<00:00, 22.63it/s]
#   objects passing mag cut: 41254
# Propagate with newton: 100%|██████████| 1/1 [00:00<00:00, 54.77it/s]
#   visible for conditional cloner: 6060
# Propagate with newton: 100%|██████████| 7/7 [00:00<00:00, 29.75it/s]
#   final cloned visible points: 479647
#   building density map with k_eff = 5 (n_visible = 479647)
# Evaluating density map: 100%|██████████| 25921/25921 [02:11<00:00, 196.49it/s]
# Trojans done.
#   raw cloned max density   : 702578138.931139
#   downweighted max density : 7025781.38931139
#
# ================================================================================
# Running all populations for mag bin: mag24+
#
# [lon180_lat0] MBA with mag cut 24.0 to 26.0...
# Propagate with newton: 100%|██████████| 139/139 [00:06<00:00, 20.20it/s]
#   objects passing mag cut: 4620900
# Propagate with newton: 100%|██████████| 47/47 [00:02<00:00, 20.04it/s]
#   visible for conditional cloner: 670364
