# %%
# %pip install line_profiler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: line_profiler in /astro/users/ds2004/.local/lib/python3.11/site-packages (5.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gprofiler-official
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gprofiler-official in /astro/users/ds2004/.local/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: requests in /astro/users/brantd/.conda/envs/lsdb_latest/lib/python3.11/site-packages (from gprofiler-official) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /astro/users/brantd/.conda/envs/lsdb_latest/lib/python3.11/site-packages (from requests->gprofiler-official) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /astro/users/brantd/.conda/envs/lsdb_latest/lib/python3.11/site-packages (from requests->gprofiler-official) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /astro/users/brantd/.conda/envs/lsdb_latest/lib/python3.11/site-packages (from requests->gprofiler-official) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /astro/users/brantd/.conda/envs/lsdb_latest/lib/python3.11/site-packages (from requests->gprofiler-official) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyinstrument
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyinstrument in /astro/users/ds2004/.local/lib/python3.11/site-packages (5.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
from urllib.request import urlopen
from io import StringIO
import numpy as np
import astropy.units as u
from astropy.time import Time
from numpy import sin, cos
from astropy.coordinates import EarthLocation, get_body_barycentric_posvel, solar_system_ephemeris 
from astropy.coordinates import SkyCoord, get_sun, GCRS
import pyarrow as pa
import adam_core.coordinates
from adam_core.time import Timestamp
from adam_core.coordinates import CartesianCoordinates, Origin
from adam_core.constants import KM_P_AU, S_P_DAY
from adam_core.orbits import Orbits
from adam_core.utils import get_perturber_state
from adam_core.coordinates.origin import OriginCodes
from scipy.interpolate import RegularGridInterpolator

#importing the neomod3.py file for the 4D array
import NEOMOD3 as nm3

# %%
df, array4D, H_center, a_center, e_center, i_center = nm3.getNEOMOD3orbits()

# %%
AU_km = 149_597_870.7
mu_sun = 1.32712440018e11  # [km^3/s^2] gm of the sun
ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 10.0, 20.0, 0.12, 0.22

rubin_location = EarthLocation.from_geodetic( 
        lon=-70.7366*u.deg,   # longitude (west is negative)
        lat=-30.2407*u.deg,   # latitude
        height=2647*u.m       # elevation
        
    )

def get_earth_and_observer(obstime_str): # 1.47 ms -> 1.27 ms
    obstime = Time(obstime_str)
    
    obs_geo = rubin_location.get_gcrs(obstime)
    r_obs =  obs_geo.cartesian.xyz.to_value(u.km).T
    
    # earth's barycentric vector rel to sun aka center of solsys to earth
    with solar_system_ephemeris.set('de432s'): 
        rE_bary, vE_bary = get_body_barycentric_posvel('earth', obstime)

    # convert to km and km/s arrays in cartesian coordinate system
    rE  = rE_bary.xyz.to_value(u.km).T #rE goes from sun to earth center
    vE  = vE_bary.xyz.to_value(u.km/u.s).T

      #vE goes from sun to earth center

    return obstime, rE, vE, r_obs
       
# creates a right-handed vector basis that points to object from observer
def sky_basis(ra_rad, dec_rad): #its already fast w 5.32 us
        l_hat = np.array([np.cos(dec_rad)*np.cos(ra_rad), # vector that points to object's pos on sky from observer
                          np.cos(dec_rad)*np.sin(ra_rad),
                          np.sin(dec_rad)])
        e_ra  = np.array([-np.sin(ra_rad), np.cos(ra_rad), 0.0]) # vector towards increasing RA - points east, 90 deg to l_hat
        e_dec = np.array([-np.sin(dec_rad)*np.cos(ra_rad), # vector towards increasing dec - points north
                          -np.sin(dec_rad)*np.sin(ra_rad),
                          np.cos(dec_rad)])
        return l_hat, e_ra, e_dec # turning angular rates into linear velocities


# split from obs_to_geocentric_state
def compute_unit_vectors(ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day): 
        mu_sun = 1.32712440018e11  # [km^3/s^2] gm of the sun

        # converting from degrees to radians
        ra  = np.deg2rad(ra_deg) 
        dec = np.deg2rad(dec_deg)
        l_hat, e_ra, e_dec = sky_basis(ra, dec)
         # angular rate conversion from deg/day to rad/s
        dra  = np.deg2rad(dra_deg_per_day)  / 86400.0
        ddec = np.deg2rad(ddec_deg_per_day) / 86400.0

        v_hat = (dra * e_ra + ddec * e_dec)

        return l_hat, v_hat

# converts vectors to geocentric state vectors 
def observables_to_geocentric_state(l_hat, v_hat, d_au, ddot_kms): 
    
        

        d_km = d_au * AU_km
        # multiplying l_hat by the rand dist. value gives actual geocentric pos vector of obj
        r_geo = np.outer(d_km, l_hat)  # vector from earth center to obj

        # speed
        v_rad = np.outer(ddot_kms, l_hat)
        v_tan = np.outer(d_km, v_hat)
        v_geo = v_rad + v_tan
        
        return r_geo, v_geo

l_hat, v_hat = compute_unit_vectors(ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day)

#converts geocentric vectors to heliocentric vectors 
def geo_to_topo(r_geo_km, v_geo_kms, rE, vE, r_obs, obstime):
        # convert r_geo, v_geo for obj to heliocentric r_topo, v_topo for an observer at rubin
        # from center of earth to an observer now at rubin
        obstime = Time(obstime)
        # earth's barycentric (heliocentric) state was done in previous step
        # so was observer's offset from center of earth
        # adding the offsets
        r_topo = rE + r_obs + r_geo_km
        v_topo = vE + v_geo_kms
        return r_topo, v_topo # asteroid position, vec going from sun to asteroid assuming youre at rubin

def to_keplerian_adam(r_helio, v_helio, obstime):
    r_vec = np.array(r_helio, dtype=float)
    v_vec = np.array(v_helio, dtype=float)

    if r_vec.ndim == 1:
        r_vec = r_vec[np.newaxis, :]
        v_vec = v_vec[np.newaxis, :]

    cartesian_coordinates = CartesianCoordinates.from_kwargs(
    x=r_vec[:, 0] / KM_P_AU,
    y=r_vec[:, 1] / KM_P_AU,
    z=r_vec[:, 2] / KM_P_AU,
    vx=v_vec[:, 0] / KM_P_AU * S_P_DAY,
    vy=v_vec[:, 1] / KM_P_AU * S_P_DAY,
    vz=v_vec[:, 2] / KM_P_AU * S_P_DAY,
    time=Timestamp.from_astropy(obstime),
    origin=Origin.from_kwargs(code=pa.repeat("SUN", len(r_vec))),
    frame="equatorial" # ecliptic is the other choice
    )

    keplerian_coordinates = cartesian_coordinates.to_keplerian()


    # Might be useful to store them into an orbits object:
    orbits = Orbits.from_kwargs(
        orbit_id=[f"orbit_{i:08d}" for i in range(len(cartesian_coordinates))],
        coordinates=cartesian_coordinates,
    )

    a_val = keplerian_coordinates.a[0].as_py()
    e_val = keplerian_coordinates.e[0].as_py()
    i_val = keplerian_coordinates.i[0].as_py()
    return a_val, e_val, i_val
# The Orbits class expects cartesian coordinates but its trivial to convert
    

def score_from_elements_interp(a_AU, e, H0, i0, interp4D):
    # checks if orbit is bound right
    if (a_AU <= 0) or (e >= 1.0) or (e < 0):
        
        return 0.0

    # clip to model box
    a_cl = np.clip(a_AU, 0.0, 4.2 - 1e-9)
    e_cl = np.clip(e,      0.0, 1.0 - 1e-9)
    i_cl = np.clip(i0,  0.0, 88.0 - 1e-9)

    log_w = float(interp4D([[H0, a_cl, e_cl, i_cl]])[0])
    return 0.0 if not np.isfinite(log_w) else float(np.exp(log_w))
    
def score_from_elements(a_AU, e, H0, i0, grid4D, H_center, a_center, e_center, i_center): #without interpolation
    # checks if orbit is bound right
    if (a_AU <= 0) or (e >= 1.0) or (e < 0):
        
        return 0.0

    # clip to model box
    a_cl = np.clip(a_AU, 0.0, 4.2 - 1e-9)
    e_cl = np.clip(e,    0.0, 1.0 - 1e-9)
    i_cl = np.clip(i0,  0.0, 88.0 - 1e-9)
    
    iH = int(np.argmin(np.abs(H_center - H0)))
    ia = int(np.argmin(np.abs(a_center - a_cl)))
    ie = int(np.argmin(np.abs(e_center - e_cl)))
    ii = int(np.argmin(np.abs(i_center - i_cl)))

    w=grid4D[iH, ia, ie, ii]
    if not np.isfinite(w) or w <= 0:
        return 0.0
    return float(w)



def compute_neomod3_weight(d_au, ddot_kms,array4D=array4D, H_center=H_center,
                           a_center=a_center, e_center=e_center, i_center=i_center,
                           l_hat = l_hat, v_hat = v_hat, 
                           ra_deg=10.0, dec_deg=20.0, 
                           dra_deg_per_day=0.12, ddec_deg_per_day=0.22,
                           H0=19.0, i0=25.9, obstime_str="2025-09-16T00:00:00"):
    
    
      
    obstime, rE, vE, r_obs = get_earth_and_observer(obstime_str) # first part, moved to start of cell


    r_geo, v_geo = observables_to_geocentric_state(l_hat, v_hat, d_au, ddot_kms)

    r_helio, v_helio = geo_to_topo(r_geo, v_geo, rE, vE, r_obs, obstime) 

    


    
    obstime = Time([obstime_str], scale="tdb")  # Note converted this to a list 
    a_val, e_val, i_val = to_keplerian_adam(r_helio, v_helio, obstime)


    
    
    #score = score_from_elements_interp(a_val, e_val, 19.0, i_val, interp4D)
    score = score_from_elements(
        a_val, e_val, H0, i_val,
        array4D, H_center, a_center, e_center, i_center
    )
    return score,a_val,e_val,i_val

# %%
neo_score, a, e, i = compute_neomod3_weight(d_au=0.20, ddot_kms=3.0)


test_neomod = compute_neomod3_weight( 
    d_au = 0.20,
    ddot_kms = 3.0,
    
)

print("NEOMOD3 weight score, a, e , i:", test_neomod)
print("neo_score:", neo_score)
print("a:", a)
print("e:", e)
print("i:", i)
# Out:
# NEOMOD3 weight score, a, e , i: (0.34704, 1.8347951398844098, 0.37040854569843407, 26.107074758880806)
# neo_score: 0.34704
# a: 1.8347951398844098
# e: 0.37040854569843407
# i: 26.107074758880806

# %%
from matplotlib.colors import TwoSlopeNorm


d_vals = np.linspace(0.00, 0.40, 60)   
v_vals = np.linspace(0.0, 17.0, 60)    


W = np.zeros((len(d_vals), len(v_vals)))   
A = np.zeros_like(W)                       
E = np.zeros_like(W)                       
I = np.zeros_like(W)                       


for i, d in enumerate(d_vals):
    for j, v in enumerate(v_vals):
        w, a, e, inc = compute_neomod3_weight(d_au=d, ddot_kms=v) 
        W[i, j] = w
        A[i, j] = a
        E[i, j] = e
        I[i, j] = inc


fig, axs = plt.subplots(2, 2, figsize=(12, 9), constrained_layout=True)
extent = [v_vals.min(), v_vals.max(), d_vals.min(), d_vals.max()]  # x=ddot, y=d

im0 = axs[0, 0].imshow(W, origin="lower", extent=extent, aspect="auto", cmap="inferno")
cont0 = axs[0,0].contour(v_vals, d_vals, W, levels=8, colors='white', linewidths=0.8)
axs[0,0].clabel(cont0, inline=True, fontsize=8, fmt="%.2f")
axs[0, 0].set_title("NEOMOD3 weight w(d, ddot)")
axs[0, 0].set_xlabel("ddot [km/s]")
axs[0, 0].set_ylabel("d [AU]")
fig.colorbar(im0, ax=axs[0, 0], label="w")

# semimajor axis
X, Y = np.meshgrid(v_vals, d_vals, indexing="xy")
A_mask = np.ma.masked_where(np.abs(A) > 10, A)
norm = TwoSlopeNorm(vmin=-10, vcenter=0, vmax=10)
ax = axs[0, 1]
im = ax.imshow(
    A_mask,
    origin="lower",
    extent=[v_vals.min(), v_vals.max(), d_vals.min(), d_vals.max()],
    aspect="auto",
    cmap="inferno",
    norm=norm,
)
ax.set_title("Semimajor axis a(d, ddot)")
ax.set_xlabel("ddot [km/s]")
ax.set_ylabel("d [AU]")
fig.colorbar(im, ax=ax, label="a [AU]")
levels = np.linspace(-10, 10, 21)
cs = ax.contour(X, Y, A_mask, levels=levels, colors="white", linewidths=0.8)
ax.clabel(cs, inline=True, fontsize=8, fmt="%.1f")

#im1 = axs[0, 1].imshow(A, origin="lower", extent=extent, aspect="auto", cmap="inferno", vmin=-10, vmax=10)
#cont1 = axs[0,1].contour(v_vals, d_vals, A, levels=8, colors='white', linewidths=0.8)
#axs[0,1].clabel(cont1, inline=True, fontsize=8, fmt="%.2f")

#img1 = np.copy(im1)
#img1 = np.ma.masked_where(np.abs(img1) > 10, img1)
#plt.contour(x, y, img1, levels=np.linspace(-10, 10, 21))

#axs[0, 1].set_title("Semimajor axis a(d, ddot)")
#axs[0, 1].set_xlabel("ddot [km/s]")
#axs[0, 1].set_ylabel("d [AU]")
#fig.colorbar(im1, ax=axs[0, 1], label="a [AU]")

#eccentricity
im2 = axs[1, 0].imshow(E, origin="lower", extent=extent, aspect="auto", cmap="inferno")
cont2 = axs[1,0].contour(v_vals, d_vals, E, levels=np.linspace(0, 1, 8), colors='white', linewidths=0.8)
axs[1,0].clabel(cont2, inline=True, fontsize=8, fmt="%.2f")
axs[1, 0].set_title("Eccentricity e(d, ddot)")
axs[1, 0].set_xlabel("ddot [km/s]")
axs[1, 0].set_ylabel("d [AU]")
fig.colorbar(im2, ax=axs[1, 0], label="e")

#inclination
im3 = axs[1, 1].imshow(I, origin="lower", extent=extent, aspect="auto", cmap="inferno")
cont3 = axs[1,1].contour(v_vals, d_vals, I, levels=8, colors='white', linewidths=0.8)
axs[1,1].clabel(cont3, inline=True, fontsize=8, fmt="%.1f°")
axs[1, 1].set_title("Inclination i(d, ddot)")
axs[1, 1].set_xlabel("ddot [km/s]")
axs[1, 1].set_ylabel("d [AU]")
fig.colorbar(im3, ax=axs[1, 1], label="i [deg]")

plt.show()

# %%
from matplotlib.colors import TwoSlopeNorm


d_vals = np.linspace(0.00, 0.70, 60)   
v_vals = np.linspace(-40.0, 40.0, 60)    


W = np.zeros((len(d_vals), len(v_vals)))   
A = np.zeros_like(W)                       
E = np.zeros_like(W)                       
I = np.zeros_like(W)                       


for i, d in enumerate(d_vals):
    for j, v in enumerate(v_vals):
        w, a, e, inc = compute_neomod3_weight(d_au=d, ddot_kms=v) 
        W[i, j] = w
        A[i, j] = a
        E[i, j] = e
        I[i, j] = inc


fig, axs = plt.subplots(2, 2, figsize=(12, 9), constrained_layout=True)
extent = [v_vals.min(), v_vals.max(), d_vals.min(), d_vals.max()]  # x=ddot, y=d

im0 = axs[0, 0].imshow(W, origin="lower", extent=extent, aspect="auto", cmap="inferno")
#cont0 = axs[0,0].contour(v_vals, d_vals, W, levels=8, colors='white', linewidths=0.8)
#axs[0,0].clabel(cont0, inline=True, fontsize=8, fmt="%.2f")
axs[0,0].clabel(cont0, inline=True, fontsize=8, fmt="%.2f")
axs[0, 0].set_title("NEOMOD3 weight w(d, ddot)")
axs[0, 0].set_xlabel("ddot [km/s]")
axs[0, 0].set_ylabel("d [AU]")
fig.colorbar(im0, ax=axs[0, 0], label="w")

# semimajor axis
X, Y = np.meshgrid(v_vals, d_vals, indexing="xy")
A_mask = np.ma.masked_where(np.abs(A) > 10, A)
norm = TwoSlopeNorm(vmin=-10, vcenter=0, vmax=10)
ax = axs[0, 1]
im = ax.imshow(
    A_mask,
    origin="lower",
    extent=[v_vals.min(), v_vals.max(), d_vals.min(), d_vals.max()],
    aspect="auto",
    cmap="inferno",
    norm=norm,
)
ax.set_title("Semimajor axis a(d, ddot)")
ax.set_xlabel("ddot [km/s]")
ax.set_ylabel("d [AU]")
fig.colorbar(im, ax=ax, label="a [AU]")
levels = np.linspace(-10, 10, 21)
cs = ax.contour(X, Y, A_mask, levels=levels, colors="white", linewidths=0.8)
ax.clabel(cs, inline=True, fontsize=8, fmt="%.1f")

#im1 = axs[0, 1].imshow(A, origin="lower", extent=extent, aspect="auto", cmap="inferno", vmin=-10, vmax=10)
#cont1 = axs[0,1].contour(v_vals, d_vals, A, levels=8, colors='white', linewidths=0.8)
#axs[0,1].clabel(cont1, inline=True, fontsize=8, fmt="%.2f")

#img1 = np.copy(im1)
#img1 = np.ma.masked_where(np.abs(img1) > 10, img1)
#plt.contour(x, y, img1, levels=np.linspace(-10, 10, 21))

#axs[0, 1].set_title("Semimajor axis a(d, ddot)")
#axs[0, 1].set_xlabel("ddot [km/s]")
#axs[0, 1].set_ylabel("d [AU]")
#fig.colorbar(im1, ax=axs[0, 1], label="a [AU]")

#eccentricity
im2 = axs[1, 0].imshow(E, origin="lower", extent=extent, aspect="auto", cmap="inferno")
cont2 = axs[1,0].contour(v_vals, d_vals, E, levels=np.linspace(0, 1, 8), colors='white', linewidths=0.8)
axs[1,0].clabel(cont2, inline=True, fontsize=8, fmt="%.2f")
axs[1, 0].set_title("Eccentricity e(d, ddot)")
axs[1, 0].set_xlabel("ddot [km/s]")
axs[1, 0].set_ylabel("d [AU]")
fig.colorbar(im2, ax=axs[1, 0], label="e")

#inclination
im3 = axs[1, 1].imshow(I, origin="lower", extent=extent, aspect="auto", cmap="inferno")
cont3 = axs[1,1].contour(v_vals, d_vals, I, levels=8, colors='white', linewidths=0.8)
axs[1,1].clabel(cont3, inline=True, fontsize=8, fmt="%.1f°")
axs[1, 1].set_title("Inclination i(d, ddot)")
axs[1, 1].set_xlabel("ddot [km/s]")
axs[1, 1].set_ylabel("d [AU]")
fig.colorbar(im3, ax=axs[1, 1], label="i [deg]")

plt.show()

# %%
def radec_rates_to_ecliptic_rates1(ra_deg, dec_deg, dra_deg_day, ddec_deg_day):

    
    sc_eq = SkyCoord(
        ra=ra_deg * u.deg,
        dec=dec_deg * u.deg,
        pm_ra_cosdec=dra_deg_day * u.deg / u.day,
        pm_dec=ddec_deg_day * u.deg / u.day,
        frame="icrs"
    )

    
    sc_ecl = sc_eq.transform_to(GeocentricTrueEcliptic())

    
    vlam  = sc_ecl.pm_lon_coslat.to(u.deg / u.day).value
    vbeta = sc_ecl.pm_lat.to(u.deg / u.day).value

    return vlam, vbeta

# %%
# %load_ext line_profiler

# %%
def makeddotgrids():
    d_min, d_max, Nd = 0.05, 5.0, 10          # AU  
    v_min, v_max, Nv = -60.0, 60.0, 10         # km/s

    d_grid   = np.linspace(d_min, d_max, Nd)
    ddot_grid= np.linspace(v_min, v_max, Nv)
    return d_grid, ddot_grid
    
def weight_marginalized_over_d_and_ddot(array4D, H_center, a_center, e_center, i_center,
                                        ra_deg, dec_deg, dra_deg_day, ddec_deg_day,
                                        H0=19.0, i0=25.9, obstime_str="2025-09-23T00:00:00"):
    w_sum = 0.0
    d_grid, ddot_grid = makeddotgrids()
    # loop 
    for d in d_grid:
        for vlos in ddot_grid:
            out = compute_neomod3_weight(d_au=d, ddot_kms=vlos, array4D=array4D, H_center=H_center, a_center=a_center, e_center=e_center, i_center=i_center,
                            ra_deg=ra_deg, dec_deg=dec_deg,
                            dra_deg_per_day=dra_deg_day, ddec_deg_per_day=ddec_deg_day,
                            H0=H0, i0=i0, obstime_str=obstime_str)
            w = out[0] if isinstance(out, tuple) else float(out)
            w_sum += w
    return w_sum

# %%
# %timeit -n 1 -r 3 weight_marginalized_over_d_and_ddot(array4D, H_center, a_center, e_center, i_center,ra_deg, dec_deg, dra_deg_day=0.12, ddec_deg_day=0.22)
# Out:
# 259 ms ± 2.14 ms per loop (mean ± std. dev. of 3 runs, 1 loop each)

# %%
# %prun weight_marginalized_over_d_and_ddot(array4D, H_center, a_center, e_center, i_center,ra_deg, dec_deg, dra_deg_day=0.12, ddec_deg_day=0.22)
# Out:
#          748655 function calls (726855 primitive calls) in 0.448 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       600    0.014    0.000    0.016    0.000 spk.py:202(generate)
# 2100/1100    0.014    0.000    0.034    0.000 tables.py:147(from_pyarrow)
#      2300    0.012    0.000    0.030    0.000 columns.py:232(__get__)
# 42260/27760    0.010    0.000    0.107    0.000 {built-in method builtins.getattr}
#       600    0.009    0.000    0.074    0.000 tables.py:251(from_kwargs)
#      2500    0.009    0.000    0.028    0.000 columns.py:123(_load)
#     82154    0.007    0.000    0.008    0.000 {built-in method builtins.isinstance}
#       800    0.007    0.000    0.007    0.000 compute.py:339(cast)
#     11700    0.006    0.000    0.017    0.000 quantity.py:565(__array_finalize__)
#     11600    0.006    0.000    0.008    0.000 {built-in method numpy.array}
#       800    0.006    0.000    0.011    0.000 utils.py:19(day_frac)
#      4300    0.006    0.000    0.015    0.000 quantity.py:755(_new_view)
#      4400    0.006    0.000    0.006    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       100    0.006    0.000    0.006    0.000 core.py:7029(c2i06a)
#       200    0.005    0.000    0.088    0.000 iers.py:445(_interpolate)
#       400    0.005    0.000    0.005    0.000 compute.py:239(wrapper)
#      1000    0.005    0.000    0.011    0.000 core.py:2404(_expand_and_gather)
#       600    0.004    0.000    0.016    0.000 core.py:1321(_apply)
#       600    0.004    0.000    0.005    0.000 tables.py:341(_build_arrow_table)
#      2500    0.004    0.000    0.048    0.000 formats.py:156(__init__)
#       100    0.004    0.000    0.027    0.000 transform.py:547(cartesian_to_keplerian)
#       600    0.004    0.000    0.009    0.000 tables.py:650(to_structarray)
#      1300    0.004    0.000    0.021    0.000 quantity.py:604(__array_ufunc__)
#     11600    0.003    0.000    0.006    0.000 {method 'view' of 'numpy.ndarray' objects}
#      1400    0.003    0.000    0.009    0.000 core.py:940(_shaped_like_input)
#       100    0.003    0.000    0.141    0.001 1804849192.py:88(to_keplerian_adam)
#       300    0.003    0.000    0.065    0.000 core.py:783(_set_scale)
#      1900    0.003    0.000    0.015    0.000 configuration.py:442(__call__)
#      5100    0.003    0.000    0.008    0.000 quantity.py:936(to_value)
#       400    0.003    0.000    0.013    0.000 formats.py:1630(get_jds_fast)
# 3600/1200    0.003    0.000    0.081    0.000 core.py:1758(__getattr__)
#      1300    0.003    0.000    0.008    0.000 data_info.py:355(__set__)
#      2600    0.003    0.000    0.010    0.000 fromnumeric.py:89(_wrapreduction_any_all)
#       500    0.003    0.000    0.012    0.000 base.py:150(__init__)
#      1500    0.003    0.000    0.004    0.000 tables.py:1160(_metadata_for_column)
#      2800    0.003    0.000    0.019    0.000 quantity.py:1274(__getitem__)
#     12500    0.003    0.000    0.012    0.000 {built-in method builtins.hasattr}
#       800    0.003    0.000    0.033    0.000 cartesian.py:49(__init__)
#      1900    0.003    0.000    0.004    0.000 configuration.py:547(get_config)
#       400    0.002    0.000    0.005    0.000 core.py:16575(dtf2d)
#       600    0.002    0.000    0.002    0.000 tables.py:631(chunk_counts)
#       400    0.002    0.000    0.045    0.000 core.py:584(_get_time_fmt)
#       300    0.002    0.000    0.002    0.000 attributes.py:45(__set__)
#      3800    0.002    0.000    0.003    0.000 formats.py:2503(_validate_jd_for_storage)
# 3100/2200    0.002    0.000    0.004    0.000 column.py:1270(__setattr__)
#       100    0.002    0.000    0.012    0.000 time.py:198(from_astropy)
# 22700/21900    0.002    0.000    0.002    0.000 {built-in method builtins.len}
#     13000    0.002    0.000    0.004    0.000 abc.py:117(__instancecheck__)
#  1600/600    0.002    0.000    0.021    0.000 tables.py:988(validate)
#       200    0.002    0.000    0.008    0.000 formats.py:1126(set_jds)
#       800    0.002    0.000    0.004    0.000 core.py:1135(_to)
#       100    0.002    0.000    0.006    0.000 covariances.py:103(from_matrix)
#       100    0.002    0.000    0.082    0.001 keplerian.py:250(from_cartesian)
#      1000    0.002    0.000    0.002    0.000 numeric.py:65(zeros_like)
# 3100/2800    0.002    0.000    0.006    0.000 core.py:2448(decompose)
#      2100    0.002    0.000    0.002    0.000 {method 'round' of 'numpy.generic' objects}
#       100    0.002    0.000    0.002    0.000 dispatch.py:83(apply_primitive)
#      7500    0.002    0.000    0.002    0.000 quantity.py:827(_set_unit)
#      2200    0.002    0.000    0.007    0.000 quantity.py:417(__new__)
#      2200    0.002    0.000    0.003    0.000 copy.py:128(deepcopy)
#       100    0.002    0.000    0.044    0.000 solar_system.py:199(_get_body_barycentric_posvel)
#      1300    0.002    0.000    0.008    0.000 converters.py:137(converters_and_unit)
#      1700    0.002    0.000    0.003    0.000 decorators.py:842(__get__)
#       900    0.002    0.000    0.009    0.000 base.py:723(_validate_differentials)
#     13000    0.002    0.000    0.002    0.000 {built-in method _abc._abc_instancecheck}
#     17400    0.002    0.000    0.002    0.000 {method 'get' of 'dict' objects}
#       300    0.002    0.000    0.009    0.000 _arraypad_impl.py:545(pad)
#      1100    0.002    0.000    0.002    0.000 attributes.py:34(__get__)
#       100    0.002    0.000    0.005    0.000 origin.py:127(mu)
#      3300    0.002    0.000    0.005    0.000 {built-in method builtins.any}
#      6800    0.002    0.000    0.002    0.000 formats.py:442(_select_subfmts)
#       100    0.002    0.000    0.002    0.000 core.py:16389(dtdb)
#       600    0.002    0.000    0.002    0.000 tables.py:662(<listcomp>)
#      3342    0.001    0.000    0.006    0.000 fromnumeric.py:51(_wrapfunc)
#       100    0.001    0.000    0.015    0.000 baseframe.py:1264(represent_as)
#      2500    0.001    0.000    0.002    0.000 formats.py:212(in_subfmt)
#       200    0.001    0.000    0.005    0.000 formats.py:1594(get_jds_python)
#      1300    0.001    0.000    0.001    0.000 {function Quantity.__array_ufunc__ at 0x7f0131aaaac0}
#      1200    0.001    0.000    0.007    0.000 core.py:104(check_errwarn)
#      1300    0.001    0.000    0.006    0.000 core.py:962(is_equivalent)
#       300    0.001    0.000    0.008    0.000 shape_base.py:377(stack)
#      2100    0.001    0.000    0.006    0.000 tables.py:136(__init__)
#     15100    0.001    0.000    0.001    0.000 quantity.py:1000(unit)
#       100    0.001    0.000    0.011    0.000 indexing.py:529(_attempt_rewriting_take_via_slice)
#      4100    0.001    0.000    0.002    0.000 formats.py:263(scale)
#      3800    0.001    0.000    0.002    0.000 configobj.py:550(__getitem__)
#       400    0.001    0.000    0.002    0.000 formats.py:1115(_check_val_type)
#     16900    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#       400    0.001    0.000    0.048    0.000 core.py:511(_init_from_vals)
#       100    0.001    0.000    0.448    0.004 1804849192.py:161(compute_neomod3_weight)
#      2000    0.001    0.000    0.006    0.000 quantity.py:1268(quantity_iter)
#      2200    0.001    0.000    0.002    0.000 core.py:2405(add_unit)
#      2500    0.001    0.000    0.001    0.000 formats.py:277(precision)
#      1900    0.001    0.000    0.003    0.000 formats.py:242(jd2)
#      1900    0.001    0.000    0.005    0.000 validate.py:593(check)
#       100    0.001    0.000    0.001    0.000 columns.py:252(_nulls)
# 1300/1100    0.001    0.000    0.013    0.000 {function Quantity.__array_function__ at 0x7f0131aad6c0}
#      1900    0.001    0.000    0.003    0.000 validate.py:651(_check_value)
#      2200    0.001    0.000    0.009    0.000 fromnumeric.py:2496(any)
#       100    0.001    0.000    0.002    0.000 covariances.py:55(to_matrix)
#       600    0.001    0.000    0.004    0.000 _arraypad_impl.py:470(_as_pairs)
#      1900    0.001    0.000    0.001    0.000 validate.py:637(_parse_with_caching)
#      2900    0.001    0.000    0.005    0.000 fromnumeric.py:3666(round)
# 1300/1100    0.001    0.000    0.013    0.000 quantity.py:1849(__array_function__)
#       400    0.001    0.000    0.001    0.000 _arraypad_impl.py:129(_set_pad_area)
#      1000    0.001    0.000    0.012    0.000 core.py:2328(__init__)
#       600    0.001    0.000    0.008    0.000 functools.py:981(__get__)
#       100    0.001    0.000    0.283    0.003 1804849192.py:12(get_earth_and_observer)
#      1900    0.001    0.000    0.001    0.000 data_info.py:340(__get__)
#      1600    0.001    0.000    0.001    0.000 utils.py:122(two_sum)
#       100    0.001    0.000    0.026    0.000 baseframe.py:531(__init__)
#      1600    0.001    0.000    0.007    0.000 quantity.py:685(_result_as_quantity)
#       600    0.001    0.000    0.002    0.000 quantity.py:1298(__setitem__)
#       400    0.001    0.000    0.025    0.000 formats.py:1569(set_jds)
#      1300    0.001    0.000    0.002    0.000 core.py:770(_normalize_equivalencies)
#       600    0.001    0.000    0.006    0.000 core.py:668(_physical_type_id)
#       200    0.001    0.000    0.010    0.000 core.py:992(to_value)
#      1300    0.001    0.000    0.003    0.000 {method 'any' of 'numpy.generic' objects}
#       300    0.001    0.000    0.003    0.000 numeric.py:1452(moveaxis)
#      3700    0.001    0.000    0.003    0.000 core.py:778(scale)
#       600    0.001    0.000    0.001    0.000 _stride_tricks_impl.py:427(_broadcast_shape)
#       700    0.001    0.000    0.008    0.000 core.py:810(__truediv__)
#      1200    0.001    0.000    0.002    0.000 quantity.py:1672(_to_own_unit)
#       100    0.001    0.000    0.021    0.000 baseframe.py:643(_infer_data)
#       300    0.001    0.000    0.002    0.000 _arraypad_impl.py:86(_pad_simple)
#      1002    0.001    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       200    0.001    0.000    0.029    0.000 iers.py:872(_refresh_table_as_needed)
#      1900    0.001    0.000    0.002    0.000 table.py:2071(__getitem__)
#       500    0.001    0.000    0.050    0.000 core.py:1951(__init__)
#       218    0.001    0.000    0.001    0.000 _methods.py:100(_clip)
#     11400    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#       700    0.001    0.000    0.001    0.000 {built-in method builtins.divmod}
#      1900    0.001    0.000    0.009    0.000 data_info.py:572(__set__)
#      3900    0.001    0.000    0.006    0.000 {built-in method builtins.setattr}
#      2600    0.001    0.000    0.001    0.000 fromnumeric.py:91(<dictcomp>)
#       200    0.001    0.000    0.004    0.000 iers.py:292(mjd_utc)
#      4100    0.001    0.000    0.001    0.000 formats.py:370(_check_scale)
#       300    0.001    0.000    0.013    0.000 base.py:708(__init__)
#       500    0.001    0.000    0.002    0.000 base.py:206(<listcomp>)
#       600    0.001    0.000    0.001    0.000 numeric.py:1388(normalize_axis_tuple)
#       900    0.001    0.000    0.001    0.000 core.py:2469(is_unity)
#      2500    0.001    0.000    0.001    0.000 formats.py:222(out_subfmt)
#     12000    0.001    0.000    0.001    0.000 {function Quantity.__array_finalize__ at 0x7f0131aaa980}
#      1900    0.001    0.000    0.015    0.000 configuration.py:333(__get__)
#      2000    0.001    0.000    0.001    0.000 core.py:1098(masked)
#       300    0.001    0.000    0.006    0.000 column.py:704(__array_finalize__)
#      1900    0.001    0.000    0.001    0.000 table.py:254(__getitem__)
#       100    0.001    0.000    0.029    0.000 earth.py:737(_get_gcrs_posvel)
#       200    0.001    0.000    0.002    0.000 core.py:17732(utctai)
#       500    0.001    0.000    0.002    0.000 _stride_tricks_impl.py:495(broadcast_arrays)
#       600    0.001    0.000    0.014    0.000 tables.py:1253(__arrow_array__)
#       200    0.001    0.000    0.005    0.000 column.py:324(_compare)
#       100    0.001    0.000    0.001    0.000 _stride_tricks_impl.py:350(_broadcast_to)
#      1900    0.001    0.000    0.006    0.000 configuration.py:513(_validate_val)
#       300    0.001    0.000    0.001    0.000 numeric.py:896(outer)
#       800    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#       100    0.001    0.000    0.001    0.000 dtypes.py:901(dtype)
#       100    0.001    0.000    0.003    0.000 slicing.py:1468(_slice_impl)
#      1900    0.001    0.000    0.002    0.000 formats.py:232(jd1)
#       200    0.001    0.000    0.002    0.000 formats.py:1518(parse_string)
#       300    0.001    0.000    0.010    0.000 chunking.py:4(pad_to_fixed_size)
#      3400    0.001    0.000    0.001    0.000 base.py:312(components)
#      3200    0.001    0.000    0.009    0.000 core.py:2036(__call__)
#       100    0.001    0.000    0.008    0.000 iers.py:683(pm_source)
#       700    0.001    0.000    0.001    0.000 validate.py:746(_is_num_param)
#      1400    0.001    0.000    0.002    0.000 {built-in method builtins.all}
#       500    0.001    0.000    0.001    0.000 core.py:3341(_make_array)
#      1500    0.001    0.000    0.001    0.000 quantity.py:1089(__getattr__)
#      1000    0.001    0.000    0.002    0.000 {method 'all' of 'numpy.generic' objects}
#      7100    0.001    0.000    0.001    0.000 formats.py:228(jd1)
#      1300    0.001    0.000    0.001    0.000 converters.py:174(<listcomp>)
#       900    0.001    0.000    0.001    0.000 columns.py:1436(_fast_combine_chunks)
#      1400    0.001    0.000    0.001    0.000 {built-in method numpy.asarray}
#       600    0.001    0.000    0.003    0.000 core.py:848(__mul__)
#       200    0.001    0.000    0.001    0.000 core.py:607(<listcomp>)
#       600    0.001    0.000    0.010    0.000 chunking.py:26(process_in_chunks)
#      1300    0.001    0.000    0.001    0.000 data_info.py:564(__init__)
#       600    0.001    0.000    0.001    0.000 __init__.py:272(_compile)
#       600    0.001    0.000    0.004    0.000 tables.py:642(fragmented)
#       200    0.001    0.000    0.005    0.000 base.py:1374(_get_deriv_key)
#       600    0.001    0.000    0.002    0.000 base.py:558(<dictcomp>)
#       300    0.001    0.000    0.001    0.000 util.py:296(wrapper)
#      1700    0.001    0.000    0.002    0.000 _methods.py:59(_any)
#       100    0.001    0.000    0.060    0.001 utils.py:40(get_polar_motion)
#       200    0.001    0.000    0.001    0.000 formats.py:631(to_value)
#       400    0.001    0.000    0.007    0.000 quantity.py:1200(__mul__)
#       100    0.001    0.000    0.002    0.000 lax_numpy.py:4541(concatenate)
#      1200    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:405(parent)
#      4500    0.001    0.000    0.001    0.000 {method 'encode' of 'str' objects}
#      6300    0.001    0.000    0.001    0.000 {function Section.__getitem__ at 0x7f0131f7dd00}
#       600    0.001    0.000    0.004    0.000 helpers.py:236(helper_multiplication)
#       200    0.000    0.000    0.007    0.000 cartesian.py:337(__init__)
#      1500    0.000    0.000    0.001    0.000 columns.py:595(__get__)
#       100    0.000    0.000    0.004    0.000 cartesian.py:59(values)
#      3000    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#       200    0.000    0.000    0.002    0.000 function_helpers.py:416(_quantities2arrays)
#       400    0.000    0.000    0.004    0.000 quantity.py:877(_to_value)
#       700    0.000    0.000    0.001    0.000 columns.py:715(__get__)
#       600    0.000    0.000    0.001    0.000 tables.py:219(_attribute_kwargs_from_kwargs)
#       800    0.000    0.000    0.000    0.000 {method 'round' of 'numpy.ndarray' objects}
#      5200    0.000    0.000    0.000    0.000 core.py:906(__hash__)
#       800    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#       200    0.000    0.000    0.001    0.000 core.py:16696(taitt)
#       700    0.000    0.000    0.001    0.000 baseframe.py:1924(__setattr__)
#       100    0.000    0.000    0.193    0.002 earth.py:717(get_gcrs)
#      1000    0.000    0.000    0.001    0.000 core.py:2442(<listcomp>)
#       400    0.000    0.000    0.083    0.000 utils.py:95(get_jd12)
#       500    0.000    0.000    0.004    0.000 core.py:1932(__new__)
#      1800    0.000    0.000    0.001    0.000 core.py:2439(<lambda>)
#       400    0.000    0.000    0.006    0.000 quantity.py:897(to)
#       300    0.000    0.000    0.003    0.000 column.py:1124(_copy_attrs)
#      1400    0.000    0.000    0.001    0.000 formats.py:194(_get_allowed_subfmt)
#      1000    0.000    0.000    0.002    0.000 {method 'sort' of 'list' objects}
#      3900    0.000    0.000    0.000    0.000 converters.py:179(<genexpr>)
#      1900    0.000    0.000    0.000    0.000 formats.py:2519(_broadcast_writeable)
#       400    0.000    0.000    0.000    0.000 getlimits.py:692(__init__)
#       100    0.000    0.000    0.125    0.001 intermediate_rotation_transforms.py:49(cirs_to_itrs_mat)
#       400    0.000    0.000    0.003    0.000 core.py:1170(to)
#       100    0.000    0.000    0.001    0.000 converters.py:288(check_output)
#      2700    0.000    0.000    0.001    0.000 base.py:701(<lambda>)
#      1600    0.000    0.000    0.000    0.000 pandas_compat.py:687(get_datetimetz_type)
#       100    0.000    0.000    0.009    0.000 cartesian.py:154(transform)
#       200    0.000    0.000    0.001    0.000 base.py:160(_to_string)
#       100    0.000    0.000    0.000    0.000 core.py:11164(pom00)
#      1300    0.000    0.000    0.000    0.000 core.py:991(_is_equivalent)
#       100    0.000    0.000    0.162    0.002 earth.py:772(get_gcrs_posvel)
#       200    0.000    0.000    0.001    0.000 arrayprint.py:1675(_array_str_implementation)
#       100    0.000    0.000    0.005    0.000 core.py:2585(_get_delta_tdb_tt)
#       800    0.000    0.000    0.000    0.000 formats.py:1116(<genexpr>)
#       200    0.000    0.000    0.000    0.000 formats.py:571(to_value)
#       600    0.000    0.000    0.017    0.000 core.py:1290(replicate)
#      1000    0.000    0.000    0.000    0.000 core.py:2438(<listcomp>)
#       200    0.000    0.000    0.005    0.000 iers.py:789(open)
#      2000    0.000    0.000    0.002    0.000 base.py:244(<genexpr>)
#      3200    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#       600    0.000    0.000    0.001    0.000 base.py:247(get_name)
#      1200    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#       200    0.000    0.000    0.014    0.000 core.py:2047(now)
#       100    0.000    0.000    0.001    0.000 1804849192.py:59(observables_to_geocentric_state)
#      1300    0.000    0.000    0.000    0.000 core.py:102(_normalize_equivalencies)
#      3200    0.000    0.000    0.000    0.000 core.py:1849(name)
#      1400    0.000    0.000    0.000    0.000 utils.py:184(is_effectively_unity)
#       300    0.000    0.000    0.001    0.000 fromnumeric.py:69(_wrapreduction)
#       600    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#       600    0.000    0.000    0.005    0.000 core.py:978(jd1)
#      4000    0.000    0.000    0.000    0.000 core.py:2394(bases)
#      4600    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       600    0.000    0.000    0.008    0.000 cartesian.py:119(get_xyz)
#      1300    0.000    0.000    0.000    0.000 core.py:872(out_subfmt)
#       100    0.000    0.000    0.000    0.000 _twodim_base_impl.py:163(eye)
#      1200    0.000    0.000    0.000    0.000 data_info.py:198(__get__)
#      2500    0.000    0.000    0.000    0.000 formats.py:269(scale)
#       400    0.000    0.000    0.001    0.000 validate.py:1073(is_string)
#       100    0.000    0.000    0.001    0.000 core.py:17825(utcut1)
#      1800    0.000    0.000    0.000    0.000 core.py:677(<genexpr>)
#      2100    0.000    0.000    0.001    0.000 {method 'join' of 'str' objects}
#       600    0.000    0.000    0.004    0.000 core.py:985(jd2)
#      1000    0.000    0.000    0.001    0.000 utils.py:209(sanitize_scale_value)
#      2200    0.000    0.000    0.000    0.000 tables.py:648(<genexpr>)
#       200    0.000    0.000    0.001    0.000 os.py:674(__getitem__)
#       200    0.000    0.000    0.001    0.000 arrayprint.py:540(wrapper)
#       100    0.000    0.000    0.004    0.000 1804849192.py:77(geo_to_topo)
#       100    0.000    0.000    0.011    0.000 array.py:349(__getitem__)
#       300    0.000    0.000    0.000    0.000 core.py:1112(<lambda>)
#       700    0.000    0.000    0.001    0.000 base.py:420(shape)
#      1900    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 core.py:7684(c2tcio)
#       300    0.000    0.000    0.002    0.000 shape_base.py:463(<listcomp>)
#   900/700    0.000    0.000    0.001    0.000 core.py:2265(decompose)
#       200    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#      2100    0.000    0.000    0.001    0.000 base.py:1359(<lambda>)
#       500    0.000    0.000    0.000    0.000 _stride_tricks_impl.py:556(<listcomp>)
#      1000    0.000    0.000    0.001    0.000 _methods.py:68(_all)
#       600    0.000    0.000    0.000    0.000 table.py:2245(__len__)
#       500    0.000    0.000    0.000    0.000 base.py:231(<listcomp>)
#       600    0.000    0.000    0.002    0.000 base.py:555(_units)
#       300    0.000    0.000    0.001    0.000 validate.py:839(is_float)
#      2000    0.000    0.000    0.000    0.000 core.py:1160(<genexpr>)
#       100    0.000    0.000    0.042    0.000 core.py:2536(_get_delta_ut1_utc)
#      1000    0.000    0.000    0.001    0.000 core.py:91(__get__)
#       400    0.000    0.000    0.000    0.000 copy.py:243(_keep_alive)
#       600    0.000    0.000    0.001    0.000 __init__.py:163(match)
#       200    0.000    0.000    0.001    0.000 baseframe.py:1130(get_representation_component_names)
#       100    0.000    0.000    0.000    0.000 base.py:849(_re_represent_differentials)
#       900    0.000    0.000    0.000    0.000 core.py:859(in_subfmt)
#      1200    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#   300/200    0.000    0.000    0.001    0.000 baseframe.py:1881(__getattr__)
#      2200    0.000    0.000    0.000    0.000 utils.py:260(sanitize_power)
#      1000    0.000    0.000    0.000    0.000 utils.py:300(resolve_fractions)
#      3700    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#       100    0.000    0.000    0.007    0.000 cartesian.py:286(cross)
#      1100    0.000    0.000    0.000    0.000 attributes.py:99(from_bytes)
#       200    0.000    0.000    0.005    0.000 column.py:722(__array_wrap__)
#       500    0.000    0.000    0.000    0.000 quantity.py:1260(__iter__)
#      1300    0.000    0.000    0.000    0.000 core.py:267(equivalencies)
#       400    0.000    0.000    0.000    0.000 columns.py:377(__get__)
#       100    0.000    0.000    0.000    0.000 config.py:220(trace_context)
#       600    0.000    0.000    0.001    0.000 decorators.py:753(__get__)
#       800    0.000    0.000    0.000    0.000 core.py:885(shape)
#       500    0.000    0.000    0.000    0.000 _internal.py:941(npy_ctypes_check)
#       900    0.000    0.000    0.000    0.000 core.py:846(precision)
#       100    0.000    0.000    0.001    0.000 quantity.py:1969(_wrap_function)
#       200    0.000    0.000    0.000    0.000 {method 'searchsorted' of 'numpy.ndarray' objects}
#      2900    0.000    0.000    0.000    0.000 fromnumeric.py:3662(_round_dispatcher)
#       400    0.000    0.000    0.000    0.000 _arraypad_impl.py:58(_view_roi)
#       600    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#       300    0.000    0.000    0.001    0.000 fromnumeric.py:3080(max)
#       400    0.000    0.000    0.002    0.000 fromnumeric.py:2611(all)
#      2200    0.000    0.000    0.000    0.000 fromnumeric.py:2491(_any_dispatcher)
#       200    0.000    0.000    0.014    0.000 iers.py:522(time_now)
#       200    0.000    0.000    0.012    0.000 base.py:962(with_differentials)
#       500    0.000    0.000    0.002    0.000 attributes.py:122(__get__)
#       100    0.000    0.000    0.001    0.000 core.py:17355(tttdb)
#       200    0.000    0.000    0.001    0.000 attributes.py:182(convert_input)
#      1000    0.000    0.000    0.000    0.000 data_info.py:770(name)
#       800    0.000    0.000    0.001    0.000 function_helpers.py:447(<genexpr>)
#       500    0.000    0.000    0.000    0.000 _stride_tricks_impl.py:560(<listcomp>)
#      1700    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       200    0.000    0.000    0.003    0.000 function_helpers.py:463(concatenate)
#       800    0.000    0.000    0.000    0.000 validate.py:1316(is_option)
#       100    0.000    0.000    0.000    0.000 columns.py:156(_nulls)
#      1200    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       200    0.000    0.000    0.000    0.000 {built-in method now}
#       100    0.000    0.000    0.003    0.000 covariances.py:171(is_all_nan)
#       400    0.000    0.000    0.001    0.000 base.py:460(masked)
#       200    0.000    0.000    0.001    0.000 function_helpers.py:391(_as_quantity)
#       300    0.000    0.000    0.000    0.000 shape_base.py:451(<listcomp>)
#       400    0.000    0.000    0.000    0.000 core.py:97(combine_masks)
#      1300    0.000    0.000    0.000    0.000 data_info.py:312(__init__)
#       300    0.000    0.000    0.002    0.000 earth.py:890(__getitem__)
#       100    0.000    0.000    0.004    0.000 core.py:636(_true_bind)
#       100    0.000    0.000    0.002    0.000 indexing.py:509(_is_valid_integer_index_for_slice)
#      1600    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       218    0.000    0.000    0.002    0.000 fromnumeric.py:2250(clip)
#       100    0.000    0.000    0.000    0.000 numeric.py:220(ones_like)
#         1    0.000    0.000    0.448    0.448 1470737377.py:9(weight_marginalized_over_d_and_ddot)
#      1100    0.000    0.000    0.000    0.000 quantity.py:1054(isscalar)
#       500    0.000    0.000    0.001    0.000 base.py:802(_compatible_differentials)
#       400    0.000    0.000    0.000    0.000 copy.py:227(_deepcopy_dict)
#       800    0.000    0.000    0.000    0.000 core.py:51(get_data_and_mask)
#      1000    0.000    0.000    0.000    0.000 core.py:2441(<listcomp>)
#       200    0.000    0.000    0.001    0.000 weakref.py:243(values)
#       800    0.000    0.000    0.000    0.000 _arraypad_impl.py:33(_slice_at_axis)
#      2300    0.000    0.000    0.000    0.000 formats.py:238(jd2)
#       100    0.000    0.000    0.004    0.000 core.py:2572(_set_delta_ut1_utc)
#      1100    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x866f00}
#       100    0.000    0.000    0.000    0.000 numeric.py:303(full)
#      2300    0.000    0.000    0.000    0.000 core.py:2399(powers)
#       100    0.000    0.000    0.000    0.000 weakref.py:289(update)
#      2000    0.000    0.000    0.000    0.000 core.py:2389(scale)
#       700    0.000    0.000    0.000    0.000 _arraypad_impl.py:109(<genexpr>)
#       200    0.000    0.000    0.002    0.000 formats.py:1772(parse_string)
#       200    0.000    0.000    0.000    0.000 formats.py:1282(_check_val_type)
#       100    0.000    0.000    0.001    0.000 core.py:16830(taiutc)
#       100    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#       200    0.000    0.000    0.000    0.000 columns.py:1281(__get__)
#       300    0.000    0.000    0.000    0.000 chunking.py:22(<listcomp>)
#      1500    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#       200    0.000    0.000    0.001    0.000 _collections_abc.py:771(get)
#       300    0.000    0.000    0.000    0.000 shape_base.py:455(<setcomp>)
#       300    0.000    0.000    0.001    0.000 column.py:764(name)
#   400/200    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#       400    0.000    0.000    0.002    0.000 core.py:1069(get_converter)
#      1300    0.000    0.000    0.000    0.000 core.py:385(get_current_unit_registry)
#       100    0.000    0.000    0.001    0.000 core.py:17224(tttai)
#       600    0.000    0.000    0.000    0.000 numeric.py:1439(<listcomp>)
#       200    0.000    0.000    0.000    0.000 core.py:1289(set_trace)
#      1100    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       400    0.000    0.000    0.007    0.000 quantity.py:1218(__rmul__)
#       400    0.000    0.000    0.000    0.000 core.py:1746(cache)
#       300    0.000    0.000    0.001    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.054    0.001 iers.py:385(pm_xy)
#       300    0.000    0.000    0.001    0.000 earth.py:897(__array_finalize__)
#      1200    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#       700    0.000    0.000    0.000    0.000 _arraypad_impl.py:120(<genexpr>)
#       400    0.000    0.000    0.000    0.000 indexing.py:539(<genexpr>)
#       300    0.000    0.000    0.002    0.000 {jaxlib.utils.safe_map}
#      1700    0.000    0.000    0.000    0.000 base.py:806(differentials)
#       400    0.000    0.000    0.001    0.000 base.py:1366(_check_base)
#       300    0.000    0.000    0.000    0.000 baseframe.py:933(shape)
#       100    0.000    0.000    0.082    0.001 cartesian.py:371(to_keplerian)
#      1500    0.000    0.000    0.000    0.000 formats.py:218(out_subfmt)
#      1000    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#      1326    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#       300    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#       100    0.000    0.000    0.000    0.000 baseframe.py:84(_get_repr_classes)
#       100    0.000    0.000    0.004    0.000 core.py:654(bind_with_trace)
#       800    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 fromnumeric.py:2127(shape)
#       100    0.000    0.000    0.001    0.000 util.py:163(ensure_arraylike_tuple)
#       100    0.000    0.000    0.000    0.000 core.py:12896(era00)
#       100    0.000    0.000    0.006    0.000 core.py:632(bind)
#      1500    0.000    0.000    0.000    0.000 formats.py:208(in_subfmt)
#       100    0.000    0.000    0.003    0.000 time.py:54(to_numpy)
#      1100    0.000    0.000    0.000    0.000 core.py:667(format)
#       300    0.000    0.000    0.000    0.000 core.py:3380(_check_leapsec)
#       900    0.000    0.000    0.000    0.000 {built-in method numpy.lib.array_utils.normalize_axis_index}
#       100    0.000    0.000    0.035    0.000 iers.py:319(ut1_utc)
#       200    0.000    0.000    0.000    0.000 arrayprint.py:1668(_guarded_repr_or_str)
#       400    0.000    0.000    0.000    0.000 array.py:272(ndim)
#      1804    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       300    0.000    0.000    0.006    0.000 state.py:52(get)
#      1200    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 1804849192.py:113(<listcomp>)
#       200    0.000    0.000    0.006    0.000 iers.py:1033(validate)
#       100    0.000    0.000    0.000    0.000 state.py:59(set)
#       900    0.000    0.000    0.000    0.000 array.py:264(shape)
#       100    0.000    0.000    0.002    0.000 core.py:1753(cache)
#       200    0.000    0.000    0.001    0.000 array.py:1133(_get_aval_array)
#       100    0.000    0.000    0.003    0.000 core.py:1180(process_primitive)
#       100    0.000    0.000    0.001    0.000 weakref.py:104(__init__)
#       700    0.000    0.000    0.000    0.000 helpers.py:63(get_converters_and_unit)
#       100    0.000    0.000    0.004    0.000 cartesian.py:385(from_cartesian)
#       200    0.000    0.000    0.000    0.000 indexing.py:562(<genexpr>)
#       400    0.000    0.000    0.000    0.000 validate.py:897(is_boolean)
#       100    0.000    0.000    0.003    0.000 time.py:40(mjd)
#       102    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#       100    0.000    0.000    0.000    0.000 dtypes.py:485(issubdtype)
#       200    0.000    0.000    0.002    0.000 function_helpers.py:454(_iterable_helper)
#       400    0.000    0.000    0.000    0.000 formats.py:1509(_check_val_type)
#       200    0.000    0.000    0.001    0.000 core.py:1769(get_aval)
#       100    0.000    0.000    0.000    0.000 core.py:2694(unit_scale_converter)
#       600    0.000    0.000    0.000    0.000 core.py:1941(decompose)
#       400    0.000    0.000    0.000    0.000 base.py:114(<genexpr>)
#       200    0.000    0.000    0.000    0.000 {method 'rindex' of 'str' objects}
#       300    0.000    0.000    0.000    0.000 shape_base.py:367(_stack_dispatcher)
#       200    0.000    0.000    0.000    0.000 core.py:2259(__hash__)
#       100    0.000    0.000    0.001    0.000 core.py:2057(canonicalize_value)
#       100    0.000    0.000    0.000    0.000 core.py:11920(sp00)
#      1200    0.000    0.000    0.000    0.000 multiarray.py:1101(copyto)
#       200    0.000    0.000    0.001    0.000 base.py:112(_format_unit_list)
#       100    0.000    0.000    0.006    0.000 slicing.py:60(slice)
#       200    0.000    0.000    0.000    0.000 os.py:756(encode)
#       600    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#      1200    0.000    0.000    0.000    0.000 helpers.py:31(_d)
#       100    0.000    0.000    0.001    0.000 iers.py:855(_check_interpolate_indices)
#       200    0.000    0.000    0.001    0.000 fromnumeric.py:1464(searchsorted)
#      1800    0.000    0.000    0.000    0.000 copy.py:182(_deepcopy_atomic)
#       100    0.000    0.000    0.002    0.000 decorators.py:870(__delete__)
#      1052    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#       200    0.000    0.000    0.000    0.000 core.py:1841(_get_format_name)
#        52    0.000    0.000    0.000    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#       218    0.000    0.000    0.002    0.000 {method 'clip' of 'numpy.ndarray' objects}
#      1200    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       100    0.000    0.000    0.011    0.000 indexing.py:629(rewriting_take)
#       100    0.000    0.000    0.000    0.000 1804849192.py:138(score_from_elements)
#       100    0.000    0.000    0.001    0.000 core.py:1732(_id_cache)
#      1000    0.000    0.000    0.000    0.000 multiarray.py:363(where)
#       300    0.000    0.000    0.000    0.000 shape_base.py:209(_arrays_for_stack_dispatcher)
#       400    0.000    0.000    0.000    0.000 core.py:120(<listcomp>)
#       300    0.000    0.000    0.000    0.000 solar_system.py:129(get_kernel)
#       100    0.000    0.000    0.000    0.000 core.py:103(__set__)
#       400    0.000    0.000    0.001    0.000 {method 'any' of 'numpy.ndarray' objects}
#      1200    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#      1100    0.000    0.000    0.000    0.000 multiarray.py:82(empty_like)
#      1000    0.000    0.000    0.000    0.000 numeric.py:59(_zeros_like_dispatcher)
#       100    0.000    0.000    0.044    0.000 solar_system.py:338(get_body_barycentric_posvel)
#       200    0.000    0.000    0.000    0.000 {method 'utcoffset' of 'datetime.datetime' objects}
#       200    0.000    0.000    0.001    0.000 core.py:660(__str__)
#       200    0.000    0.000    0.001    0.000 base.py:128(to_string)
#       300    0.000    0.000    0.000    0.000 column.py:596(parent_table)
#       200    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 baseframe.py:1068(_get_representation_info)
#       200    0.000    0.000    0.000    0.000 base.py:93(_format_unit_power)
#       100    0.000    0.000    0.001    0.000 base.py:894(represent_as)
#       200    0.000    0.000    0.000    0.000 getlimits.py:703(min)
#       200    0.000    0.000    0.000    0.000 indexing.py:501(_is_integer_index)
#       200    0.000    0.000    0.000    0.000 solar_system.py:120(validate)
#       300    0.000    0.000    0.000    0.000 {method 'indices' of 'slice' objects}
#       900    0.000    0.000    0.000    0.000 formats.py:273(precision)
#       100    0.000    0.000    0.015    0.000 baseframe.py:2129(cartesian)
#       200    0.000    0.000    0.004    0.000 {function BaseColumn.__array_wrap__ at 0x7f013151f4c0}
#       200    0.000    0.000    0.000    0.000 core.py:2348(<listcomp>)
#       100    0.000    0.000    0.008    0.000 intermediate_rotation_transforms.py:44(gcrs_to_cirs_mat)
#       100    0.000    0.000    0.002    0.000 time.py:93(fractional_days)
#       400    0.000    0.000    0.000    0.000 core.py:2657(_condition_arg)
#       100    0.000    0.000    0.000    0.000 weakref.py:121(_commit_removals)
#       100    0.000    0.000    0.000    0.000 _stride_tricks_impl.py:447(broadcast_shapes)
#       100    0.000    0.000    0.000    0.000 baseframe.py:1005(<dictcomp>)
#       400    0.000    0.000    0.000    0.000 base.py:715(<genexpr>)
#       600    0.000    0.000    0.000    0.000 quantity.py:737(__quantity_subclass__)
#       100    0.000    0.000    0.000    0.000 baseframe.py:615(_infer_representation)
#       300    0.000    0.000    0.000    0.000 numeric.py:1515(<listcomp>)
#       100    0.000    0.000    0.000    0.000 indexing.py:523(_is_contiguous_slice)
#       200    0.000    0.000    0.000    0.000 column.py:575(data)
#       600    0.000    0.000    0.000    0.000 baseframe.py:913(data)
#       100    0.000    0.000    0.000    0.000 _weakrefset.py:27(__exit__)
#       600    0.000    0.000    0.000    0.000 core.py:760(location)
#       300    0.000    0.000    0.000    0.000 indexing.py:600(<genexpr>)
#       300    0.000    0.000    0.000    0.000 column.py:989(unit)
#       100    0.000    0.000    0.002    0.000 indexing.py:552(<setcomp>)
#       202    0.000    0.000    0.000    0.000 fromnumeric.py:3571(ndim)
#       100    0.000    0.000    0.000    0.000 {jaxlib.utils.safe_zip}
#       300    0.000    0.000    0.000    0.000 attributes.py:96(to_bytes)
#       100    0.000    0.000    0.001    0.000 quantity.py:2043(round)
#       200    0.000    0.000    0.000    0.000 spk.py:74(__getitem__)
#       200    0.000    0.000    0.000    0.000 matrix_utilities.py:14(matrix_transpose)
#        26    0.000    0.000    0.000    0.000 ipkernel.py:790(<setcomp>)
#       100    0.000    0.000    0.000    0.000 util.py:536(canonicalize_axis)
#       100    0.000    0.000    0.000    0.000 indexing.py:551(<setcomp>)
#       902    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#       300    0.000    0.000    0.000    0.000 column.py:586(parent_table)
#       100    0.000    0.000    0.000    0.000 util.py:172(check_arraylike)
#       100    0.000    0.000    0.000    0.000 cartesian.py:387(<listcomp>)
#       100    0.000    0.000    0.000    0.000 _stride_tricks_impl.py:487(<listcomp>)
#       100    0.000    0.000    0.000    0.000 indexing.py:554(<setcomp>)
#       400    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 util.py:134(_arraylike_asarray)
#       100    0.000    0.000    0.000    0.000 shapes.py:225(size)
#       100    0.000    0.000    0.000    0.000 baseframe.py:1383(<dictcomp>)
#       100    0.000    0.000    0.000    0.000 baseframe.py:1398(<dictcomp>)
#       200    0.000    0.000    0.000    0.000 getlimits.py:716(max)
#       200    0.000    0.000    0.000    0.000 util.py:175(<genexpr>)
#       100    0.000    0.000    0.001    0.000 _stride_tricks_impl.py:377(broadcast_to)
#       100    0.000    0.000    0.000    0.000 core.py:1798(_match_shape)
#       200    0.000    0.000    0.000    0.000 enum.py:1232(__hash__)
#       100    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 util.py:87(promote_dtypes)
#       300    0.000    0.000    0.000    0.000 indexing.py:534(<genexpr>)
#       100    0.000    0.000    0.000    0.000 dataclasses.py:1258(is_dataclass)
#       100    0.000    0.000    0.000    0.000 enum.py:806(__members__)
#       400    0.000    0.000    0.000    0.000 array.py:280(sharding)
#       500    0.000    0.000    0.000    0.000 core.py:710(powers)
#       100    0.000    0.000    0.000    0.000 baseframe.py:1002(get_frame_attr_defaults)
#       200    0.000    0.000    0.000    0.000 utils.py:196(sanitize_scale_type)
#        26    0.000    0.000    0.000    0.000 threading.py:1501(enumerate)
#       200    0.000    0.000    0.000    0.000 lax.py:140(asarray)
#       100    0.000    0.000    0.000    0.000 base.py:986(<listcomp>)
#       300    0.000    0.000    0.000    0.000 core.py:2757(is_symbolic_dim)
#       600    0.000    0.000    0.000    0.000 core.py:1727(is_unity)
#       100    0.000    0.000    0.000    0.000 sharding_impls.py:957(is_single_device_sharding)
#       100    0.000    0.000    0.000    0.000 weakref.py:347(__new__)
#       200    0.000    0.000    0.000    0.000 tables.py:740(__len__)
#       600    0.000    0.000    0.000    0.000 typing.py:2287(cast)
#       100    0.000    0.000    0.000    0.000 time.py:512(rescale)
#       200    0.000    0.000    0.000    0.000 sharding_impls.py:131(__hash__)
#       300    0.000    0.000    0.000    0.000 _stride_tricks_impl.py:355(<genexpr>)
#       100    0.000    0.000    0.000    0.000 _weakrefset.py:21(__enter__)
#       400    0.000    0.000    0.000    0.000 fromnumeric.py:2606(_all_dispatcher)
#       100    0.000    0.000    0.000    0.000 shapes.py:230(isscalar)
#       100    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 baseframe.py:1122(representation_info)
#       100    0.000    0.000    0.000    0.000 weakref.py:352(__init__)
#       100    0.000    0.000    0.000    0.000 enum.py:193(__get__)
#       500    0.000    0.000    0.000    0.000 core.py:705(bases)
#       200    0.000    0.000    0.000    0.000 quantity.py:2002(<genexpr>)
#       100    0.000    0.000    0.000    0.000 sharding_impls.py:144(num_devices)
#       100    0.000    0.000    0.001    0.000 {method 'min' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 indexing.py:504(_is_simple_reverse_slice)
#       300    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       500    0.000    0.000    0.000    0.000 _stride_tricks_impl.py:491(_broadcast_arrays_dispatcher)
#       100    0.000    0.000    0.000    0.000 array.py:609(_check_if_deleted)
#       100    0.000    0.000    0.000    0.000 indexing.py:601(<listcomp>)
#       100    0.000    0.000    0.000    0.000 _function_base_impl.py:346(iterable)
#       300    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#       200    0.000    0.000    0.000    0.000 util.py:169(<genexpr>)
#       100    0.000    0.000    0.000    0.000 baseframe.py:53(_get_repr_cls)
#       500    0.000    0.000    0.000    0.000 core.py:700(scale)
#       300    0.000    0.000    0.000    0.000 iers.py:159(_none_to_float)
#       200    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#       100    0.000    0.000    0.001    0.000 earth.py:875(x)
#       100    0.000    0.000    0.000    0.000 indexing.py:602(<listcomp>)
#       100    0.000    0.000    0.000    0.000 util.py:91(<listcomp>)
#       100    0.000    0.000    0.000    0.000 baseframe.py:891(cache)
#       100    0.000    0.000    0.000    0.000 sharding_impls.py:148(device_set)
#       234    0.000    0.000    0.000    0.000 threading.py:1168(ident)
#       100    0.000    0.000    0.000    0.000 shapes.py:239(__bool__)
#       100    0.000    0.000    0.000    0.000 core.py:2268(is_unity)
#        52    0.000    0.000    0.000    0.000 __init__.py:127(_xla_gc_callback)
#       300    0.000    0.000    0.000    0.000 column.py:757(name)
#       200    0.000    0.000    0.000    0.000 baseframe.py:1007(get_representation_cls)
#       200    0.000    0.000    0.000    0.000 baseframe.py:885(getter)
#       200    0.000    0.000    0.000    0.000 columns.py:100(fill_default)
#       200    0.000    0.000    0.000    0.000 core.py:1713(<lambda>)
#       218    0.000    0.000    0.000    0.000 fromnumeric.py:2245(_clip_dispatcher)
#       300    0.000    0.000    0.000    0.000 column.py:978(unit)
#       100    0.000    0.000    0.000    0.000 state.py:17(__exit__)
#       100    0.000    0.000    0.000    0.000 solar_system.py:143(kernel)
#       100    0.000    0.000    0.000    0.000 {built-in method math.prod}
#       300    0.000    0.000    0.000    0.000 fromnumeric.py:3075(_max_dispatcher)
#       300    0.000    0.000    0.000    0.000 multiarray.py:161(concatenate)
#       100    0.000    0.000    0.000    0.000 base.py:791(_raise_if_has_differentials)
#       100    0.000    0.000    0.001    0.000 _methods.py:47(_amin)
#       200    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#       100    0.000    0.000    0.000    0.000 core.py:1173(check_eval_args)
#       300    0.000    0.000    0.000    0.000 _arraypad_impl.py:537(_pad_dispatcher)
#       100    0.000    0.000    0.001    0.000 earth.py:880(y)
#       100    0.000    0.000    0.000    0.000 mesh.py:543(empty)
#         1    0.000    0.000    0.448    0.448 {built-in method builtins.exec}
#       100    0.000    0.000    0.000    0.000 _stride_tricks_impl.py:30(_maybe_view_as_subclass)
#       300    0.000    0.000    0.000    0.000 numeric.py:892(_outer_dispatcher)
#       300    0.000    0.000    0.000    0.000 numeric.py:1448(_moveaxis_dispatcher)
#         2    0.000    0.000    0.000    0.000 function_base.py:25(linspace)
#       100    0.000    0.000    0.000    0.000 _weakrefset.py:17(__init__)
#       200    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#       100    0.000    0.000    0.000    0.000 util.py:129(_arraylike)
#       100    0.000    0.000    0.001    0.000 earth.py:885(z)
#        18    0.000    0.000    0.000    0.000 fromnumeric.py:41(_wrapit)
#       200    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#       200    0.000    0.000    0.000    0.000 fromnumeric.py:1460(_searchsorted_dispatcher)
#       200    0.000    0.000    0.000    0.000 indexing.py:536(<genexpr>)
#       100    0.000    0.000    0.000    0.000 enum.py:788(__getitem__)
#       200    0.000    0.000    0.000    0.000 indexing.py:543(<genexpr>)
#       100    0.000    0.000    0.000    0.000 core.py:1575(full_lower)
#       100    0.000    0.000    0.000    0.000 enum.py:1257(value)
#       100    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#       100    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#       202    0.000    0.000    0.000    0.000 fromnumeric.py:3567(_ndim_dispatcher)
#       100    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#       100    0.000    0.000    0.000    0.000 state.py:10(__init__)
#       100    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#       200    0.000    0.000    0.000    0.000 multiarray.py:684(result_type)
#       100    0.000    0.000    0.000    0.000 cartesian.py:195(<dictcomp>)
#       100    0.000    0.000    0.000    0.000 base.py:1477(represent_as)
#        24    0.000    0.000    0.000    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 core.py:87(default_factory)
#       100    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#       100    0.000    0.000    0.000    0.000 baseframe.py:926(has_data)
#        24    0.000    0.000    0.000    0.000 fromnumeric.py:1366(argmin)
#       100    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       100    0.000    0.000    0.000    0.000 _stride_tricks_impl.py:373(_broadcast_to_dispatcher)
#       100    0.000    0.000    0.000    0.000 multiarray.py:560(can_cast)
#       100    0.000    0.000    0.000    0.000 numeric.py:214(_ones_like_dispatcher)
#       100    0.000    0.000    0.000    0.000 fromnumeric.py:2123(_shape_dispatcher)
#       100    0.000    0.000    0.000    0.000 state.py:14(__enter__)
#       100    0.000    0.000    0.000    0.000 cartesian.py:151(to_cartesian)
#       100    0.000    0.000    0.000    0.000 core.py:698(is_high)
#         1    0.000    0.000    0.000    0.000 1470737377.py:1(makeddotgrids)
#        20    0.000    0.000    0.000    0.000 {method 'as_arrays' of 'numpy._core._multiarray_umath._array_converter' objects}
#        20    0.000    0.000    0.000    0.000 {method 'wrap' of 'numpy._core._multiarray_umath._array_converter' objects}
#        24    0.000    0.000    0.000    0.000 fromnumeric.py:1362(_argmin_dispatcher)
#         1    0.000    0.000    0.448    0.448 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 numeric.py:1937(isscalar)
#         2    0.000    0.000    0.000    0.000 {method 'result_type' of 'numpy._core._multiarray_umath._array_converter' objects}
#         2    0.000    0.000    0.000    0.000 function_base.py:20(_linspace_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
import sys
from IPython.display import HTML
from pyinstrument import Profiler
profiler = Profiler()
profiler.start()

weight_marginalized_over_d_and_ddot(array4D, H_center, a_center, e_center, i_center,ra_deg, dec_deg, dra_deg_day=0.12, ddec_deg_day=0.22)

profiler.stop()
profiler.print()
from IPython.display import display, HTML
display(HTML(profiler.output_html()))
# Out:
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 19:11:17  Samples:  202
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 0.349     CPU time: 0.360
# /   _/                      v5.1.1
#
# Profile at /tmp/ipykernel_3223909/3930706994.py:5
#
# 0.347 <module>  /tmp/ipykernel_3223909/3930706994.py:1
# └─ 0.347 weight_marginalized_over_d_and_ddot  /tmp/ipykernel_3223909/1470737377.py:9
#    └─ 0.345 compute_neomod3_weight  /tmp/ipykernel_3223909/1804849192.py:161
#       ├─ 0.205 get_earth_and_observer  /tmp/ipykernel_3223909/1804849192.py:12
#       │  ├─ 0.137 EarthLocation.get_gcrs  astropy/coordinates/earth.py:717
#       │  │     [64 frames hidden]  astropy, copy, <built-in>, numpy
#       │  ├─ 0.045 get_body_barycentric_posvel  astropy/coordinates/solar_system.py:338
#       │  │     [4 frames hidden]  astropy
#       │  │        0.045 _get_body_barycentric_posvel  astropy/coordinates/solar_system.py:199
#       │  │        └─ 0.026 Segment.generate  jplephem/spk.py:202
#       │  ├─ 0.015 Time.__init__  astropy/time/core.py:1951
#       │  │     [4 frames hidden]  astropy
#       │  └─ 0.004 GCRS.cartesian  astropy/coordinates/baseframe.py:2129
#       │     └─ 0.004 GCRS.represent_as  astropy/coordinates/baseframe.py:1264
#       ├─ 0.124 to_keplerian_adam  /tmp/ipykernel_3223909/1804849192.py:88
#       │  ├─ 0.073 CartesianCoordinates.to_keplerian  adam_core/coordinates/cartesian.py:371
#       │  │  └─ 0.073 KeplerianCoordinates.from_cartesian  adam_core/coordinates/keplerian.py:250
#       │  │     ├─ 0.020 cartesian_to_keplerian  adam_core/coordinates/transform.py:547
#       │  │     │  ├─ 0.014 ArrayImpl.__getitem__  jax/_src/array.py:349
#       │  │     │  │  └─ 0.014 rewriting_take  jax/_src/numpy/indexing.py:629
#       │  │     │  │     └─ 0.014 _attempt_rewriting_take_via_slice  jax/_src/numpy/indexing.py:529
#       │  │     │  │        └─ 0.009 slice  jax/_src/lax/slicing.py:60
#       │  │     │  │           └─ 0.009 Primitive.bind  jax/_src/core.py:632
#       │  │     │  │              └─ 0.009 Primitive._true_bind  jax/_src/core.py:636
#       │  │     │  │                 └─ 0.007 Primitive.bind_with_trace  jax/_src/core.py:654
#       │  │     │  │                    └─ 0.007 EvalTrace.process_primitive  jax/_src/core.py:1180
#       │  │     │  │                       └─ 0.007 _slice_impl  jax/_src/lax/slicing.py:1468
#       │  │     │  │                          └─ 0.006 apply_primitive  jax/_src/dispatch.py:83
#       │  │     │  └─ 0.004 process_in_chunks  adam_core/utils/chunking.py:26
#       │  │     │     └─ 0.004 pad_to_fixed_size  adam_core/utils/chunking.py:4
#       │  │     │        └─ 0.004 pad  numpy/lib/_arraypad_impl.py:545
#       │  │     ├─ 0.018 KeplerianCoordinates.from_kwargs  quivr/tables.py:251
#       │  │     │  └─ 0.014 KeplerianCoordinates.from_pyarrow  quivr/tables.py:147
#       │  │     │     └─ 0.012 KeplerianCoordinates.validate  quivr/tables.py:988
#       │  │     │        └─ 0.012 SubTableColumn.__get__  quivr/columns.py:232
#       │  │     │           ├─ 0.006 [self]  quivr/columns.py
#       │  │     │           └─ 0.004 Timestamp.from_pyarrow  quivr/tables.py:147
#       │  │     ├─ 0.010 SubTableColumn.__get__  quivr/columns.py:232
#       │  │     │  ├─ 0.006 Origin.from_pyarrow  quivr/tables.py:147
#       │  │     │  └─ 0.004 [self]  quivr/columns.py
#       │  │     ├─ 0.008 Origin.mu  adam_core/coordinates/origin.py:127
#       │  │     ├─ 0.006 Timestamp.to_numpy  adam_core/time/time.py:54
#       │  │     └─ 0.005 CoordinateCovariances.from_matrix  adam_core/coordinates/covariances.py:103
#       │  │        └─ 0.005 CoordinateCovariances.from_kwargs  quivr/tables.py:251
#       │  ├─ 0.034 Orbits.from_kwargs  quivr/tables.py:251
#       │  │  ├─ 0.015 Orbits.from_pyarrow  quivr/tables.py:147
#       │  │  │  └─ 0.013 Orbits.validate  quivr/tables.py:988
#       │  │  │     ├─ 0.007 SubTableColumn.__get__  quivr/columns.py:232
#       │  │  │     └─ 0.006 CartesianCoordinates.validate  quivr/tables.py:988
#       │  │  │        └─ 0.006 SubTableColumn.__get__  quivr/columns.py:232
#       │  │  └─ 0.014 SubTableColumn._load  quivr/columns.py:123
#       │  │     ├─ 0.006 Timestamp.__arrow_array__  quivr/tables.py:1253
#       │  │     │  └─ 0.005 Timestamp.to_structarray  quivr/tables.py:650
#       │  │     └─ 0.006 [self]  quivr/columns.py
#       │  └─ 0.015 Timestamp.from_astropy  adam_core/time/time.py:198
#       │     └─ 0.015 Timestamp.from_kwargs  quivr/tables.py:251
#       │        ├─ 0.010 Int64Column._load  quivr/columns.py:123
#       │        └─ 0.005 [self]  quivr/tables.py
#       └─ 0.010 Time.__init__  astropy/time/core.py:1951
#             [4 frames hidden]  astropy
# <!DOCTYPE html>
#             <html>
#             <head>
#                 <meta charset="utf-8">
#             </head>
#             <body>
#                 <div id="app"></div>
#
#                 <script>var pyinstrumentHTMLRenderer=function(){"use strict";var is=Object.defineProperty;var ns=(F,ve,Pe)=>ve in F?is(F,ve,{enumerable:!0,configurable:!0,writable:!0,value:Pe}):F[ve]=Pe;var T=(F,ve,Pe)=>ns(F,typeof ve!="symbol"?ve+"":ve,Pe);function F(){}function ve(i){return i()}function Pe(){return Object.create(null)}function oe(i){i.forEach(ve)}function pt(i){return typeof i=="function"}function re(i,e){return i!=i?e==e:i!==e||i&&typeof i=="object"||typeof i=="function"}function ki(i){return Object.keys(i).length===0}function St(i,...e){if(i==null){for(const n of e)n(void 0);return F}const t=i.subscribe(...e);return t.unsubscribe?()=>t.unsubscribe():t}function ge(i,e,t){i.$$.on_destroy.push(St(e,t))}function Ci(i,e,t){return i.set(t),e}function u(i,e){i.appendChild(e)}function S(i,e,t){i.insertBefore(e,t||null)}function L(i){i.parentNode&&i.parentNode.removeChild(i)}function f(i){return document.createElement(i)}function V(i){return document.createElementNS("http://www.w3.org/2000/svg",i)}function I(i){return document.createTextNode(i)}function b(){return I(" ")}function Mi(){return I("")}function x(i,e,t,n){return i.addEventListener(e,t,n),()=>i.removeEventListener(e,t,n)}function vt(i){return function(e){return e.preventDefault(),i.call(this,e)}}function gt(i){return function(e){return e.stopPropagation(),i.call(this,e)}}function a(i,e,t){t==null?i.removeAttribute(e):i.getAttribute(e)!==t&&i.setAttribute(e,t)}function _t(i){let e;return{p(...t){e=t,e.forEach(n=>i.push(n))},r(){e.forEach(t=>i.splice(i.indexOf(t),1))}}}function Fi(i){return Array.from(i.childNodes)}function _e(i,e){e=""+e,i.data!==e&&(i.data=e)}function ae(i,e){i.value=e??""}function j(i,e,t,n){t==null?i.style.removeProperty(e):i.style.setProperty(e,t,"")}function Ee(i,e,t){i.classList.toggle(e,!!t)}function Pi(i,e,{bubbles:t=!1,cancelable:n=!1}={}){return new CustomEvent(i,{detail:e,bubbles:t,cancelable:n})}class Ri{constructor(e=!1){T(this,"is_svg",!1);T(this,"e");T(this,"n");T(this,"t");T(this,"a");this.is_svg=e,this.e=this.n=null}c(e){this.h(e)}m(e,t,n=null){this.e||(this.is_svg?this.e=V(t.nodeName):this.e=f(t.nodeType===11?"TEMPLATE":t.nodeName),this.t=t.tagName!=="TEMPLATE"?t:t.content,this.c(e)),this.i(n)}h(e){this.e.innerHTML=e,this.n=Array.from(this.e.nodeName==="TEMPLATE"?this.e.content.childNodes:this.e.childNodes)}i(e){for(let t=0;t<this.n.length;t+=1)S(this.t,this.n[t],e)}p(e){this.d(),this.h(e),this.i(this.a)}d(){this.n.forEach(L)}}let Ye;function Xe(i){Ye=i}function wt(){if(!Ye)throw new Error("Function called outside component initialization");return Ye}function bt(i){wt().$$.on_mount.push(i)}function Ii(i){wt().$$.on_destroy.push(i)}function Li(){const i=wt();return(e,t,{cancelable:n=!1}={})=>{const s=i.$$.callbacks[e];if(s){const l=Pi(e,t,{cancelable:n});return s.slice().forEach(r=>{r.call(i,l)}),!l.defaultPrevented}return!0}}const Se=[],ke=[];let De=[];const Dt=[],Si=Promise.resolve();let yt=!1;function Di(){yt||(yt=!0,Si.then(Ht))}function Tt(i){De.push(i)}const At=new Set;let He=0;function Ht(){if(He!==0)return;const i=Ye;do{try{for(;He<Se.length;){const e=Se[He];He++,Xe(e),Hi(e.$$)}}catch(e){throw Se.length=0,He=0,e}for(Xe(null),Se.length=0,He=0;ke.length;)ke.pop()();for(let e=0;e<De.length;e+=1){const t=De[e];At.has(t)||(At.add(t),t())}De.length=0}while(Se.length);for(;Dt.length;)Dt.pop()();yt=!1,At.clear(),Xe(i)}function Hi(i){if(i.fragment!==null){i.update(),oe(i.before_update);const e=i.dirty;i.dirty=[-1],i.fragment&&i.fragment.p(i.ctx,e),i.after_update.forEach(Tt)}}function Oi(i){const e=[],t=[];De.forEach(n=>i.indexOf(n)===-1?e.push(n):t.push(n)),t.forEach(n=>n()),De=e}const nt=new Set;let Re;function Oe(){Re={r:0,c:[],p:Re}}function Ve(){Re.r||oe(Re.c),Re=Re.p}function D(i,e){i&&i.i&&(nt.delete(i),i.i(e))}function N(i,e,t,n){if(i&&i.o){if(nt.has(i))return;nt.add(i),Re.c.push(()=>{nt.delete(i),n&&(t&&i.d(1),n())}),i.o(e)}else n&&n()}function Ot(i){return(i==null?void 0:i.length)!==void 0?i:Array.from(i)}function ...

# %%
from pyinstrument import Profiler
from IPython.display import display, HTML

p = Profiler(); p.start()
weight_marginalized_over_d_and_ddot(array4D, H_center, a_center, e_center, i_center,ra_deg, dec_deg, dra_deg_day=0.12, ddec_deg_day=0.22)
p.stop()

html = p.output_html()
display(HTML(html))                 
from IPython.display import FileLink, display
# Out:
# <!DOCTYPE html>
#             <html>
#             <head>
#                 <meta charset="utf-8">
#             </head>
#             <body>
#                 <div id="app"></div>
#
#                 <script>var pyinstrumentHTMLRenderer=function(){"use strict";var is=Object.defineProperty;var ns=(F,ve,Pe)=>ve in F?is(F,ve,{enumerable:!0,configurable:!0,writable:!0,value:Pe}):F[ve]=Pe;var T=(F,ve,Pe)=>ns(F,typeof ve!="symbol"?ve+"":ve,Pe);function F(){}function ve(i){return i()}function Pe(){return Object.create(null)}function oe(i){i.forEach(ve)}function pt(i){return typeof i=="function"}function re(i,e){return i!=i?e==e:i!==e||i&&typeof i=="object"||typeof i=="function"}function ki(i){return Object.keys(i).length===0}function St(i,...e){if(i==null){for(const n of e)n(void 0);return F}const t=i.subscribe(...e);return t.unsubscribe?()=>t.unsubscribe():t}function ge(i,e,t){i.$$.on_destroy.push(St(e,t))}function Ci(i,e,t){return i.set(t),e}function u(i,e){i.appendChild(e)}function S(i,e,t){i.insertBefore(e,t||null)}function L(i){i.parentNode&&i.parentNode.removeChild(i)}function f(i){return document.createElement(i)}function V(i){return document.createElementNS("http://www.w3.org/2000/svg",i)}function I(i){return document.createTextNode(i)}function b(){return I(" ")}function Mi(){return I("")}function x(i,e,t,n){return i.addEventListener(e,t,n),()=>i.removeEventListener(e,t,n)}function vt(i){return function(e){return e.preventDefault(),i.call(this,e)}}function gt(i){return function(e){return e.stopPropagation(),i.call(this,e)}}function a(i,e,t){t==null?i.removeAttribute(e):i.getAttribute(e)!==t&&i.setAttribute(e,t)}function _t(i){let e;return{p(...t){e=t,e.forEach(n=>i.push(n))},r(){e.forEach(t=>i.splice(i.indexOf(t),1))}}}function Fi(i){return Array.from(i.childNodes)}function _e(i,e){e=""+e,i.data!==e&&(i.data=e)}function ae(i,e){i.value=e??""}function j(i,e,t,n){t==null?i.style.removeProperty(e):i.style.setProperty(e,t,"")}function Ee(i,e,t){i.classList.toggle(e,!!t)}function Pi(i,e,{bubbles:t=!1,cancelable:n=!1}={}){return new CustomEvent(i,{detail:e,bubbles:t,cancelable:n})}class Ri{constructor(e=!1){T(this,"is_svg",!1);T(this,"e");T(this,"n");T(this,"t");T(this,"a");this.is_svg=e,this.e=this.n=null}c(e){this.h(e)}m(e,t,n=null){this.e||(this.is_svg?this.e=V(t.nodeName):this.e=f(t.nodeType===11?"TEMPLATE":t.nodeName),this.t=t.tagName!=="TEMPLATE"?t:t.content,this.c(e)),this.i(n)}h(e){this.e.innerHTML=e,this.n=Array.from(this.e.nodeName==="TEMPLATE"?this.e.content.childNodes:this.e.childNodes)}i(e){for(let t=0;t<this.n.length;t+=1)S(this.t,this.n[t],e)}p(e){this.d(),this.h(e),this.i(this.a)}d(){this.n.forEach(L)}}let Ye;function Xe(i){Ye=i}function wt(){if(!Ye)throw new Error("Function called outside component initialization");return Ye}function bt(i){wt().$$.on_mount.push(i)}function Ii(i){wt().$$.on_destroy.push(i)}function Li(){const i=wt();return(e,t,{cancelable:n=!1}={})=>{const s=i.$$.callbacks[e];if(s){const l=Pi(e,t,{cancelable:n});return s.slice().forEach(r=>{r.call(i,l)}),!l.defaultPrevented}return!0}}const Se=[],ke=[];let De=[];const Dt=[],Si=Promise.resolve();let yt=!1;function Di(){yt||(yt=!0,Si.then(Ht))}function Tt(i){De.push(i)}const At=new Set;let He=0;function Ht(){if(He!==0)return;const i=Ye;do{try{for(;He<Se.length;){const e=Se[He];He++,Xe(e),Hi(e.$$)}}catch(e){throw Se.length=0,He=0,e}for(Xe(null),Se.length=0,He=0;ke.length;)ke.pop()();for(let e=0;e<De.length;e+=1){const t=De[e];At.has(t)||(At.add(t),t())}De.length=0}while(Se.length);for(;Dt.length;)Dt.pop()();yt=!1,At.clear(),Xe(i)}function Hi(i){if(i.fragment!==null){i.update(),oe(i.before_update);const e=i.dirty;i.dirty=[-1],i.fragment&&i.fragment.p(i.ctx,e),i.after_update.forEach(Tt)}}function Oi(i){const e=[],t=[];De.forEach(n=>i.indexOf(n)===-1?e.push(n):t.push(n)),t.forEach(n=>n()),De=e}const nt=new Set;let Re;function Oe(){Re={r:0,c:[],p:Re}}function Ve(){Re.r||oe(Re.c),Re=Re.p}function D(i,e){i&&i.i&&(nt.delete(i),i.i(e))}function N(i,e,t,n){if(i&&i.o){if(nt.has(i))return;nt.add(i),Re.c.push(()=>{nt.delete(i),n&&(t&&i.d(1),n())}),i.o(e)}else n&&n()}function Ot(i){return(i==null?void 0:i.length)!==void 0?i:Array.from(i)}function ...

# %%
from IPython.display import HTML
from pyinstrument import Profiler
profiler = Profiler()
profiler.start()

weight_marginalized_over_d_and_ddot(array4D, H_center, a_center, e_center, i_center,ra_deg, dec_deg, dra_deg_day=0.12, ddec_deg_day=0.22)

profiler.stop()
profiler.print()
with open("profile_report.html", "w") as f:
    f.write(profiler.output_html())
# Out:
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 19:11:18  Samples:  209
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 0.358     CPU time: 0.367
# /   _/                      v5.1.1
#
# Profile at /tmp/ipykernel_3223909/3656242287.py:4
#
# 0.357 <module>  /tmp/ipykernel_3223909/3656242287.py:1
# └─ 0.357 weight_marginalized_over_d_and_ddot  /tmp/ipykernel_3223909/1470737377.py:9
#    └─ 0.357 compute_neomod3_weight  /tmp/ipykernel_3223909/1804849192.py:161
#       ├─ 0.216 get_earth_and_observer  /tmp/ipykernel_3223909/1804849192.py:12
#       │  ├─ 0.132 EarthLocation.get_gcrs  astropy/coordinates/earth.py:717
#       │  │     [63 frames hidden]  astropy, erfa
#       │  ├─ 0.043 get_body_barycentric_posvel  astropy/coordinates/solar_system.py:338
#       │  │     [6 frames hidden]  astropy, erfa, numpy
#       │  │        0.043 _get_body_barycentric_posvel  astropy/coordinates/solar_system.py:199
#       │  │        └─ 0.022 Segment.generate  jplephem/spk.py:202
#       │  ├─ 0.027 Time.__init__  astropy/time/core.py:1951
#       │  │     [5 frames hidden]  astropy
#       │  ├─ 0.008 GCRS.cartesian  astropy/coordinates/baseframe.py:2129
#       │  │  └─ 0.008 GCRS.represent_as  astropy/coordinates/baseframe.py:1264
#       │  └─ 0.004 CartesianRepresentation.get_xyz  astropy/coordinates/representation/cartesian.py:119
#       ├─ 0.122 to_keplerian_adam  /tmp/ipykernel_3223909/1804849192.py:88
#       │  ├─ 0.068 CartesianCoordinates.to_keplerian  adam_core/coordinates/cartesian.py:371
#       │  │  └─ 0.068 KeplerianCoordinates.from_cartesian  adam_core/coordinates/keplerian.py:250
#       │  │     ├─ 0.022 cartesian_to_keplerian  adam_core/coordinates/transform.py:547
#       │  │     │  ├─ 0.011 process_in_chunks  adam_core/utils/chunking.py:26
#       │  │     │  │  └─ 0.011 pad_to_fixed_size  adam_core/utils/chunking.py:4
#       │  │     │  │     └─ 0.011 pad  numpy/lib/_arraypad_impl.py:545
#       │  │     │  │           [2 frames hidden]  numpy
#       │  │     │  ├─ 0.007 ArrayImpl.__getitem__  jax/_src/array.py:349
#       │  │     │  │  └─ 0.006 rewriting_take  jax/_src/numpy/indexing.py:629
#       │  │     │  │     └─ 0.006 _attempt_rewriting_take_via_slice  jax/_src/numpy/indexing.py:529
#       │  │     │  └─ 0.004 [self]  adam_core/coordinates/transform.py
#       │  │     ├─ 0.019 SubTableColumn.__get__  quivr/columns.py:232
#       │  │     │  └─ 0.016 Timestamp.from_pyarrow  quivr/tables.py:147
#       │  │     ├─ 0.013 KeplerianCoordinates.from_kwargs  quivr/tables.py:251
#       │  │     │  └─ 0.008 KeplerianCoordinates.from_pyarrow  quivr/tables.py:147
#       │  │     │     └─ 0.005 KeplerianCoordinates.validate  quivr/tables.py:988
#       │  │     │        └─ 0.005 SubTableColumn.__get__  quivr/columns.py:232
#       │  │     ├─ 0.005 Timestamp.to_numpy  adam_core/time/time.py:54
#       │  │     │  └─ 0.004 Timestamp.mjd  adam_core/time/time.py:40
#       │  │     │     └─ 0.004 Timestamp.fractional_days  adam_core/time/time.py:93
#       │  │     │        └─ 0.004 wrapper  pyarrow/compute.py:239
#       │  │     ├─ 0.004 Origin.mu  adam_core/coordinates/origin.py:127
#       │  │     └─ 0.004 CoordinateCovariances.from_matrix  adam_core/coordinates/covariances.py:103
#       │  │        └─ 0.004 CoordinateCovariances.from_kwargs  quivr/tables.py:251
#       │  ├─ 0.039 Orbits.from_kwargs  quivr/tables.py:251
#       │  │  ├─ 0.020 CartesianCoordinates.from_pyarrow  quivr/tables.py:147
#       │  │  │  └─ 0.016 CartesianCoordinates.validate  quivr/tables.py:988
#       │  │  │     ├─ 0.011 SubTableColumn.__get__  quivr/columns.py:232
#       │  │  │     │  ├─ 0.006 Timestamp.from_pyarrow  quivr/tables.py:147
#       │  │  │     │  └─ 0.005 [self]  quivr/columns.py
#       │  │  │     └─ 0.005 CartesianCoordinates.validate  quivr/tables.py:988
#       │  │  │        └─ 0.005 SubTableColumn.__get__  quivr/columns.py:232
#       │  │  └─ 0.015 SubTableColumn._load  quivr/columns.py:123
#       │  │     └─ 0.011 CartesianCoordinates.__arrow_array__  quivr/tables.py:1253
#       │  │        └─ 0.010 CartesianCoordinates.to_structarray  quivr/tables.py:650
#       │  │           └─ 0.008 CartesianCoordinates.fragmented  quivr/tables.py:642
#       │  │              └─ 0.006 CartesianCoordinates.chunk_counts  quivr/tables.py:631
#       │  ├─ 0.011 Timestamp.from_astropy  adam_core/time/time.py:198
#       │  │  └─ 0.011 Timestamp.from_kwargs  quivr/tables.py:251
#       │  └─ 0.004 [self]  /tmp/ipykernel_3223909/1804849192.py
#       └─ 0.019 Time.__init__  astropy/time/core.py:1951
#             [8 frames hidden]  astropy

# %%
df, array4D, H_center, a_center, e_center, i_center = nm3.getNEOMOD3orbits()

# %%
import matplotlib.pyplot as plt

# anti-Sun at Sep 23 = equinox so RA = 0, Dec = 0
ra0_deg, dec0_deg = 0.0, 0.0
obstime_str = "2025-09-23T00:00:00"

 
N_rate = 31
dra_vals  = np.linspace(-0.6, 0.6, N_rate)
ddec_vals = np.linspace(-0.6, 0.6, N_rate)


vlam_edges = np.linspace(-0.6, 0.6, 121)
vbet_edges = np.linspace(-0.6, 0.6, 121)


H = np.zeros((len(vbet_edges)-1, len(vlam_edges)-1), dtype=float)

for dra in dra_vals:
    for ddec in ddec_vals:
        vlam, vbet = radec_rates_to_ecliptic_rates(ra0_deg, dec0_deg, dra, ddec)
        w_int = weight_marginalized_over_d_and_ddot(array4D=array4D, H_center=H_center, a_center=a_center, e_center=e_center, i_center=i_center,
                                                    ra_deg=ra0_deg, dec_deg=dec0_deg, dra_deg_day=dra, ddec_deg_day=ddec,
                                                    H0=19.0, i0=25.9, obstime_str=obstime_str)
        
        i = np.searchsorted(vlam_edges, vlam) - 1
        j = np.searchsorted(vbet_edges, vbet) - 1
        if 0 <= i < H.shape[1] and 0 <= j < H.shape[0]:
            H[j, i] += w_int
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 21
#      19 for dra in dra_vals:
#      20     for ddec in ddec_vals:
# ---> 21         vlam, vbet = radec_rates_to_ecliptic_rates(ra0_deg, dec0_deg, dra, ddec)
#      22         w_int = weight_marginalized_over_d_and_ddot(array4D=array4D, H_center=H_center, a_center=a_center, e_center=e_center, i_center=i_center,
#      23                                                     ra_deg=ra0_deg, dec_deg=dec0_deg, dra_deg_day=dra, ddec_deg_day=ddec,
#      24                                                     H0=19.0, i0=25.9, obstime_str=obstime_str)
#      26         i = np.searchsorted(vlam_edges, vlam) - 1
#
# NameError: name 'radec_rates_to_ecliptic_rates' is not defined

# %%
# %timeit weight_marginalized_over_d_and_ddot(array4D, H_center, a_center, e_center, i_center, ra_deg, dec_deg, dra_deg_day = 0.12, ddec_deg_day=0.22,H0=19.0, i0=25.9, obstime_str="2025-09-23T00:00:00")

# %%
# CELL ABOVE TAKES 9 MINS TO RUN DO NOT RUN AGAIN ON ACCIDENT OR ITS AN UNSKIPPABLE CUTSCENE!!!
from matplotlib import cm
plt.figure(figsize=(6.0, 6.0))
extent = [vlam_edges[0], vlam_edges[-1], vbet_edges[0], vbet_edges[-1]]
 
my_viridis = cm.get_cmap("viridis", 1024).with_extremes(under="white")
im = plt.imshow(H, origin="lower", extent=extent, cmap=my_viridis, aspect="equal")


plt.colorbar(label="NEOMOD3 weight (marginalized over d, ddot)")

plt.axhline(0, color="0.8", lw=1)
plt.axvline(0, color="0.8", lw=1)
plt.xlabel(r"$v_\lambda$ (deg/day)")
plt.ylabel(r"$v_\beta$ (deg/day)")
#plt.title("v_lambda–v_beta distribution (integrated over d [0.05,5] AU, ddot [−60,60] km/s)\n"
#          f"{obstime_str}")
plt.tight_layout()
plt.show()
