# %%
## automatically reload any modules read below that might have changed (e.g. plots)
# %reload_ext autoreload
# %autoreload 2

# %%
# importing plotting and locus tools: 
import NEOfaster as nf
import NEOMOD3 as nm3

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
from urllib.request import urlopen
from io import StringIO
import numpy as np
import astropy.units as u
from astropy.time import Time
from numpy import sin, cos
from astropy.coordinates import EarthLocation, get_body_barycentric_posvel, solar_system_ephemeris 
from astropy.coordinates import SkyCoord, get_sun, GCRS, GeocentricTrueEcliptic
import pyarrow as pa
import adam_core.coordinates
from adam_core.time import Timestamp
from adam_core.coordinates import CartesianCoordinates, Origin
from adam_core.constants import KM_P_AU, S_P_DAY
from adam_core.orbits import Orbits
from adam_core.utils import get_perturber_state
from adam_core.coordinates.origin import OriginCodes
from scipy.interpolate import RegularGridInterpolator

#importing the neomod3.py file for the 4D array
import NEOMOD3 as nm3

# %%
df, array4D, H_center, a_center, e_center, i_center = nm3.getNEOMOD3orbits()

# %%
obstime_str="2025-09-23T00:00:00"
#ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 186.35, -5.0, 46.27, -19.0
ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day = 10.0, 20.0, 0.12, 0.22
# anti-Sun at Sep 23 = equinox so RA = 0, Dec = 0
ra0_deg, dec0_deg = 0.0, 0.0

# %%
l_hat, v_hat = nf.compute_unit_vectors(ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day)
obstime, rE, vE, r_obs = nf.get_earth_and_observer(obstime_str) 
neo_score, a, e, i = nf.compute_neomod3_weight(0.2, 3.0, l_hat, v_hat, obstime, rE, vE, r_obs, array4D, H_center, a_center, e_center, i_center)




print("neo_score:", neo_score)
print("a:", a)
print("e:", e)
print("i:", i)
# Out:
# neo_score: 0.40217
# a: 1.8147948989466378
# e: 0.358504361404317
# i: 26.36952675502365

# %%
def comp_sum():
    
    N_rate = 31           #2 mins 30 sec, for 31 = 4 mins 20 sec so around 50 mins for 101 --> 1 min 40 s for 31
    dra_vals  = np.linspace(-0.6, 0.6, N_rate)
    ddec_vals = np.linspace(-0.6, 0.6, N_rate)
    
    
    vlam_edges = np.linspace(-0.6, 0.6, N_rate)
    vbet_edges = np.linspace(-0.6, 0.6, N_rate)
    
    
    H = np.zeros((len(vbet_edges)-1, len(vlam_edges)-1), dtype=float)
    
    for dra in dra_vals:
        for ddec in ddec_vals:
            vlam, vbet = nf.radec_rates_to_ecliptic_rates1(ra0_deg, dec0_deg, dra, ddec)
            w_int = nf.weight_marginalized_over_d_and_ddot(array4D=array4D, H_center=H_center, a_center=a_center, e_center=e_center, i_center=i_center,
                                                        ra_deg=ra0_deg, dec_deg=dec0_deg, dra_deg_per_day=dra, ddec_deg_per_day=ddec,
                                                         obstime_str=obstime_str)
            
            i = np.searchsorted(vlam_edges, vlam) - 1
            j = np.searchsorted(vbet_edges, vbet) - 1
            if 0 <= i < H.shape[1] and 0 <= j < H.shape[0]:
                H[j, i] += w_int
            #print(w_int, dra, ddec)
        #break
    extent = [vlam_edges[0], vlam_edges[-1], vbet_edges[0], vbet_edges[-1]]
    return H, extent

H, extent= comp_sum()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 30
#      27     extent = [vlam_edges[0], vlam_edges[-1], vbet_edges[0], vbet_edges[-1]]
#      28     return H, extent
# ---> 30 H, extent= comp_sum()
#
# Cell In[27], line 17, in comp_sum()
#      15 for ddec in ddec_vals:
#      16     vlam, vbet = nf.radec_rates_to_ecliptic_rates1(ra0_deg, dec0_deg, dra, ddec)
# ---> 17     w_int = nf.weight_marginalized_over_d_and_ddot(array4D=array4D, H_center=H_center, a_center=a_center, e_center=e_center, i_center=i_center,
#      18                                                 ra_deg=ra0_deg, dec_deg=dec0_deg, dra_deg_per_day=dra, ddec_deg_per_day=ddec,
#      19                                                  obstime_str=obstime_str)
#      21     i = np.searchsorted(vlam_edges, vlam) - 1
#      22     j = np.searchsorted(vbet_edges, vbet) - 1
#
# File <string>:8, in weight_marginalized_over_d_and_ddot(array4D, H_center, a_center, e_center, i_center, ra_deg, dec_deg, dra_deg_per_day, ddec_deg_per_day, obstime_str)
#
# File <string>:4, in compute_neomod3_weight(d_au, ddot_kms, l_hat, v_hat, obstime, rE, vE, r_obs, array4D, H_center, a_center, e_center, i_center)
#
# File ~/digest3/NEOfaster.py:238, in to_keplerian_adam(r_helio, v_helio, obstime)
#     234 def score_from_elements(a_AU, e, H0, i0, grid4D, H_center, a_center, e_center, i_center): #without interpolation
#     235     # checks if orbit is bound right
#     236     if (a_AU <= 0) or (e >= 1.0) or (e < 0):
# --> 238         return 0.0
#     240     # clip to model box
#     241     a_cl = np.clip(a_AU, 0.0, 4.2 - 1e-9)
#
# File ~/.local/lib/python3.11/site-packages/adam_core/coordinates/cartesian.py:375, in CartesianCoordinates.to_keplerian(self)
#     371 def to_keplerian(self) -> keplerian.KeplerianCoordinates:
#     372     """
#     373     Converts the Cartesian coordinates to the Keplerian parameterization.
#     374     """
# --> 375     return keplerian.KeplerianCoordinates.from_cartesian(self)
#
# File ~/.local/lib/python3.11/site-packages/adam_core/coordinates/keplerian.py:255, in KeplerianCoordinates.from_cartesian(cls, cartesian)
#     252 from .transform import _cartesian_to_keplerian6, cartesian_to_keplerian
#     254 # Extract gravitational parameter from origin
# --> 255 mu = cartesian.origin.mu()
#     257 coords_keplerian = cartesian_to_keplerian(
#     258     cartesian.values,
#     259     cartesian.time.to_numpy(),
#     260     mu=mu,
#     261 )
#     262 coords_keplerian = np.array(coords_keplerian)
#
# File ~/.local/lib/python3.11/site-packages/adam_core/coordinates/origin.py:142, in Origin.mu(self)
#     128 """
#     129 Return the gravitational parameter of the origin.
#     130
#    (...)    139     If the origin code is not recognized.
#     140 """
#     141 mu = np.empty(len(self.code), dtype=np.float64)
# --> 142 for code in pc.unique(self.code):
#     143     code = code.as_py()
#     144     mask = pc.equal(self.code, code).to_numpy(zero_copy_only=False)
#
# File /astro/users/brantd/.conda/envs/lsdb_latest/lib/python3.11/site-packages/pyarrow/compute.py:247, in _make_generic_wrapper.<locals>.wrapper(memory_pool, *args)
#     245 if args and isinstance(args[0], Expression):
#     246     return Expression._call(func_name, list(args))
# --> 247 return func.call(args, None, memory_pool)
#
# KeyboardInterrupt:

# %%
def comp_sum2():
    
    N_rate = 31           #2 mins 30 sec, for 31 = 4 mins 20 sec so around 50 mins for 101 --> 1 min 40 s for 31
    dra_vals  = np.linspace(-0.6, 0.6, N_rate)
    ddec_vals = np.linspace(-0.6, 0.6, N_rate)
    
    
    
    H = np.zeros((len(dra_vals), len(ddec_vals)), dtype=float)
    
    for i,dra in enumerate(dra_vals):
        for j,ddec in enumerate(ddec_vals):
            vlam, vbet = nf.radec_rates_to_ecliptic_rates1(ra0_deg, dec0_deg, dra, ddec)
            w_int = nf.weight_marginalized_over_d_and_ddot(array4D=array4D, H_center=H_center, a_center=a_center, e_center=e_center, i_center=i_center,
                                                        ra_deg=ra0_deg, dec_deg=dec0_deg, dra_deg_per_day=dra, ddec_deg_per_day=ddec,
                                                         obstime_str=obstime_str)
            

            H[j, i] = w_int
            #print(w_int, dra, ddec)
        #break
    extent = [dra_vals[0], dra_vals[-1], ddec_vals[0], ddec_vals[-1]]
    return H, extent

H, extent= comp_sum2()

# %%
def comp_sum1():
    
    N_rate = 31           #2 mins 30 sec, for 31 = 4 mins 20 sec so around 50 mins for 101 --> 1 min 40 s for 31
    vlam_min, vlam_max = -0.6, 0.6
    vbet_min, vbet_max = -0.6, 0.6

    vlam_vals  = np.linspace(vlam_min, vlam_max, N_rate)
    vbet_vals = np.linspace(vbet_min, vbet_max, N_rate)
    vlam_deg_day = 0.12
    vbeta_deg_day = 0.22
    

    
    
    K = np.zeros((len(vlam_vals), len(vbet_vals)), dtype=float)
    
    for i,vlam in enumerate(vlam_vals):
        for j,vbet in enumerate(vbet_vals):
            dra, ddec = nf. ecliptic_rates_to_radec_rates(ra0_deg, dec0_deg, vlam, vbet)
            w_int = nf.weight_marginalized_over_d_and_ddot(array4D=array4D, H_center=H_center, a_center=a_center, e_center=e_center, i_center=i_center,
                                                        ra_deg=ra0_deg, dec_deg=dec0_deg, dra_deg_per_day=dra, ddec_deg_per_day=ddec,
                                                        H0=19.0, i0=25.9, obstime_str=obstime_str)
            

            K[j, i] = w_int
            #print(w_int, dra, ddec)
        #break
    extent = [vlam_vals[0], vlam_vals[-1], vbet_vals[0], vbet_vals[-1]]
    return K, extent

K, extent= comp_sum1()

# %%
from matplotlib import cm
plt.figure(figsize=(6.0, 6.0))
 
my_viridis = cm.get_cmap("viridis", 1024).with_extremes(under="white")
im = plt.imshow(H, origin="lower", extent=extent, cmap=my_viridis, aspect="equal")


plt.colorbar(label="NEOMOD3 weight (marginalized over d, ddot)")

plt.axhline(0, color="0.8", lw=1)
plt.axvline(0, color="0.8", lw=1)
plt.xlabel(r"$v_\lambda$ (deg/day)")
plt.ylabel(r"$v_\beta$ (deg/day)")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2178440/3141553312.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   my_viridis = cm.get_cmap("viridis", 1024).with_extremes(under="white")

# %%
# VERSION WITH FLIPPED DRA VLAMBDA
from matplotlib import cm
plt.figure(figsize=(6.0, 6.0))
 
my_viridis = cm.get_cmap("viridis", 1024).with_extremes(under="white")
im = plt.imshow(K, origin="lower", extent=extent, cmap=my_viridis, aspect="equal")


plt.colorbar(label="NEOMOD3 weight (marginalized over d, ddot)")

plt.axhline(0, color="0.8", lw=1)
plt.axvline(0, color="0.8", lw=1)
plt.xlabel(r"$v_\lambda$ (deg/day)")
plt.ylabel(r"$v_\beta$ (deg/day)")
plt.tight_layout()
plt.show()

print("Min:", np.nanmin(K))
print("Max:", np.nanmax(K))
print("Mean:", np.nanmean(K))
print("Std:", np.nanstd(K))
print("Variance:", np.nanvar(K))
plt.figure()
plt.hist(K.flatten(), bins=30, color='slateblue', edgecolor='white')
plt.xlabel("Weight value")
plt.ylabel("Count of bins")
plt.title("Distribution of NEOMOD3 weights")
plt.show()
nonzero = K[K > 0]
print("Nonzero mean:", np.mean(nonzero))
print("Nonzero std:", np.std(nonzero))
# Out:
# /tmp/ipykernel_2178440/3747956131.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   my_viridis = cm.get_cmap("viridis", 1024).with_extremes(under="white")
# Min: 0.33686860199999996
# Max: 3.4719870449999997
# Mean: 0.5866864470735231
# Std: 0.2721912191353652
# Variance: 0.07408805977439639
# Nonzero mean: 0.5866864470735231
# Nonzero std: 0.2721912191353652

# %%
# VERSION WITH FLIPPED DRA VLAMBDA
from matplotlib import cm
plt.figure(figsize=(6.0, 6.0))
 
my_viridis = cm.get_cmap("viridis", 1024).with_extremes(under="white")
im = plt.imshow(K, origin="lower", extent=extent, cmap=my_viridis, aspect="equal")


plt.colorbar(label="NEOMOD3 weight (marginalized over d, ddot)")

plt.axhline(0, color="0.8", lw=1)
plt.axvline(0, color="0.8", lw=1)
plt.xlabel(r"$v_\lambda$ (deg/day)")
plt.ylabel(r"$v_\beta$ (deg/day)")
plt.tight_layout()
plt.show()

print("Min:", np.nanmin(K))
print("Max:", np.nanmax(K))
print("Mean:", np.nanmean(K))
print("Std:", np.nanstd(K))
print("Variance:", np.nanvar(K))
plt.figure()
plt.hist(K.flatten(), bins=30, color='slateblue', edgecolor='white')
plt.xlabel("Weight value")
plt.ylabel("Count of bins")
plt.title("Distribution of NEOMOD3 weights")
plt.show()
nonzero = K[K > 0]
print("Nonzero mean:", np.mean(nonzero))
print("Nonzero std:", np.std(nonzero))

#######################################
vlam_edges = np.linspace(-0.6, 0.6, 121)
vbet_edges = np.linspace(-0.6, 0.6, 121)
cx = 0.5 * (vlam_edges[:-1] + vlam_edges[1:])
cy = 0.5 * (vbet_edges[:-1] + vbet_edges[1:])
X, Y = np.meshgrid(cx, cy, indexing="xy")

plt.figure(figsize=(6, 6))
step = vlam_edges[1] - vlam_edges[0]
size_pts2 = (step / (vlam_edges[-1] - vlam_edges[0]) * 6000.0)**2  # adjusts to fill grid visually

sc = plt.scatter(X.ravel(), Y.ravel(), c=K.ravel(), s=size_pts2,
                 cmap=my_viridis, marker="s")
plt.colorbar(sc, label="NEOMOD3 weight (marginalized over d, ddot)")
plt.axhline(0, color="0.8", lw=1)
plt.axvline(0, color="0.8", lw=1)
plt.xlabel(r"$v_{\lambda}$ (deg/day)")
plt.ylabel(r"$v_{\beta}$ (deg/day)")
plt.gca().set_aspect("equal")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_219405/2823242792.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   my_viridis = cm.get_cmap("viridis", 1024).with_extremes(under="white")
# Min: 0.0
# Max: 3.135013106999999
# Mean: 0.01645419989545818
# Std: 0.10993463061605996
# Variance: 0.012085623008689548
# Nonzero mean: 0.5923511962364946
# Nonzero std: 0.3065112618179089

# %%
from IPython.display import HTML
from pyinstrument import Profiler
profiler = Profiler()
profiler.start()

nf.weight_marginalized_over_d_and_ddot(array4D=array4D, H_center=H_center, a_center=a_center, e_center=e_center, i_center=i_center,
                                                        ra_deg=ra0_deg, dec_deg=dec0_deg, dra_deg_per_day=dra, ddec_deg_per_day=ddec,
                                                        H0=19.0, i0=25.9, obstime_str=obstime_str)

profiler.stop()
profiler.print()
with open("profile_report.html", "w") as f:
    f.write(profiler.output_html())
# Out:
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 12:18:48  Samples:  160
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 0.160     CPU time: 0.171
# /   _/                      v5.1.1
#
# Profile at /tmp/ipykernel_219405/3116584518.py:4
#
# 0.160 <module>  /tmp/ipykernel_219405/3116584518.py:1
# └─ 0.160 weight_marginalized_over_d_and_ddot  NEOfaster.py:70
#    ├─ 0.154 compute_neomod3_weight  NEOfaster.py:239
#    │  ├─ 0.151 to_keplerian_adam  NEOfaster.py:166
#    │  │  ├─ 0.085 CartesianCoordinates.to_keplerian  adam_core/coordinates/cartesian.py:371
#    │  │  │  └─ 0.085 KeplerianCoordinates.from_cartesian  adam_core/coordinates/keplerian.py:250
#    │  │  │     ├─ 0.032 cartesian_to_keplerian  adam_core/coordinates/transform.py:547
#    │  │  │     │  ├─ 0.015 process_in_chunks  adam_core/utils/chunking.py:26
#    │  │  │     │  │  └─ 0.015 pad_to_fixed_size  adam_core/utils/chunking.py:4
#    │  │  │     │  │     └─ 0.013 pad  numpy/lib/_arraypad_impl.py:545
#    │  │  │     │  │           [7 frames hidden]  numpy, <built-in>
#    │  │  │     │  ├─ 0.009 ArrayImpl.__getitem__  jax/_src/array.py:349
#    │  │  │     │  │  └─ 0.008 rewriting_take  jax/_src/numpy/indexing.py:629
#    │  │  │     │  │     └─ 0.008 _attempt_rewriting_take_via_slice  jax/_src/numpy/indexing.py:529
#    │  │  │     │  │        └─ 0.006 slice  jax/_src/lax/slicing.py:60
#    │  │  │     │  │           └─ 0.006 Primitive.bind  jax/_src/core.py:632
#    │  │  │     │  │              └─ 0.005 Primitive._true_bind  jax/_src/core.py:636
#    │  │  │     │  │                 └─ 0.005 Primitive.bind_with_trace  jax/_src/core.py:654
#    │  │  │     │  │                    └─ 0.004 EvalTrace.process_primitive  jax/_src/core.py:1180
#    │  │  │     │  │                       └─ 0.003 _slice_impl  jax/_src/lax/slicing.py:1468
#    │  │  │     │  │                          └─ 0.003 apply_primitive  jax/_src/dispatch.py:83
#    │  │  │     │  ├─ 0.006 [self]  adam_core/coordinates/transform.py
#    │  │  │     │  └─ 0.002 concatenate  jax/_src/numpy/lax_numpy.py:4541
#    │  │  │     ├─ 0.017 KeplerianCoordinates.from_kwargs  quivr/tables.py:251
#    │  │  │     │  ├─ 0.010 SubTableColumn._load  quivr/columns.py:123
#    │  │  │     │  │  ├─ 0.008 CoordinateCovariances.__arrow_array__  quivr/tables.py:1253
#    │  │  │     │  │  │  ├─ 0.005 CoordinateCovariances.to_structarray  quivr/tables.py:650
#    │  │  │     │  │  │  └─ 0.003 cast  pyarrow/compute.py:339
#    │  │  │     │  │  └─ 0.002 [self]  quivr/columns.py
#    │  │  │     │  └─ 0.005 KeplerianCoordinates.from_pyarrow  quivr/tables.py:147
#    │  │  │     │     └─ 0.004 KeplerianCoordinates.validate  quivr/tables.py:988
#    │  │  │     │        └─ 0.004 SubTableColumn.__get__  quivr/columns.py:232
#    │  │  │     │           └─ 0.004 Timestamp.from_pyarrow  quivr/tables.py:147
#    │  │  │     ├─ 0.012 SubTableColumn.__get__  quivr/columns.py:232
#    │  │  │     │  ├─ 0.006 Timestamp.from_pyarrow  quivr/tables.py:147
#    │  │  │     │  ├─ 0.004 CartesianCoordinates._metadata_for_column  quivr/tables.py:1160
#    │  │  │     │  └─ 0.002 [self]  quivr/columns.py
#    │  │  │     ├─ 0.009 CoordinateCovariances.from_matrix  adam_core/coordinates/covariances.py:103
#    │  │  │     │  ├─ 0.007 CoordinateCovariances.from_kwargs  quivr/tables.py:251
#    │  │  │     │  │  └─ 0.004 LargeListColumn._load  quivr/columns.py:123
#    │  │  │     │  │     └─ 0.003 cast  pyarrow/compute.py:339
#    │  │  │     │  └─ 0.002 [self]  adam_core/coordinates/covariances.py
#    │  │  │     ├─ 0.005 [self]  adam_core/coordinates/keplerian.py
#    │  │  │     ├─ 0.003 Origin.mu  adam_core/coordinates/origin.py:127
#    │  │  │     ├─ 0.002 CoordinateCovariances.is_all_nan  adam_core/coordinates/covariances.py:171
#    │  │  │     │  └─ 0.002 CoordinateCovariances.to_matrix  adam_core/coordinates/covariances.py:55
#    │  │  │     │     └─ 0.002 full  numpy/_core/numeric.py:303
#    │  │  │     └─ 0.002 CartesianCoordinates.values  adam_core/coordinates/cartesian.py:59
#    │  │  ├─ 0.055 CartesianCoordinates.from_kwargs  quivr/tables.py:251
#    │  │  │  ├─ 0.025 Orbits.from_pyarrow  quivr/tables.py:147
#    │  │  │  │  ├─ 0.022 Orbits.validate  quivr/tables.py:988
#    │  │  │  │  │  ├─ 0.017 SubTableColumn.__get__  quivr/columns.py:232
#    │  │  │  │  │  │  ├─ 0.008 CartesianCoordinates.from_pyarrow  quivr/tables.py:147
#    │  │  │  │  │  │  │  ├─ 0.004 [self]  quivr/tables.py
#    │  │  │  │  │  │  │  └─ 0.003 CartesianCoordinates.__init__  quivr/tables.py:136
#    │  │  │  │  │  │  │     └─ 0.003 StringAttribute.__get__  quivr/attributes.py:34
#    │  │  │  │  │  │  └─ 0.008 [self]  quivr/columns.py
#    │  │  │  │  │  └─ 0.005 CartesianCoordinates.validate  quivr/tables.py:988
#    │  │  │  │  │     └─ 0.004 SubTableColumn.__get__  quivr/columns.py:232
#    │  │  │  │  │        └─ 0.003 Origin.from_pyarrow  quivr/tables.py:147
#    │  │  │  │  └─ 0.003 [self]  quivr/tables.py
#    │  │  │  ├─ 0.021 SubTableColumn._load  quivr/columns.py:123
#    │  │  │  │  ├─ 0.017 CartesianCoordinates.__arrow_array__  quivr/tables.py:1253
#    │  │  │  │  │  ├─ 0.008 Timestamp.to_structarray  quivr/tables.py:650
#    │  │  │  │  │  │  ├─ 0.004 [self]  quivr/tables.py
#    │  │  │  │  │  │  └─ 0.003 CartesianCoordinates.fragmented  quivr/tables.py:642
#    │  │  │  │  │  │     └─ 0.003 CartesianCoordinates.chunk_counts  quivr/tables.py:631
#    │  │  │  │  │  └─ 0.008 cast  pyarrow/compute.py:339
#    │  │  │  │  └─ 0.002 SubTableColumn._nulls  quivr/columns.py:252
#    │  │  │  ├─ 0.005 [self]  quivr/tables.py
#    │  │  │  └─ 0.002 CartesianCoordinates._build_arrow_table  quivr/tables.py:341
#    │  │  ├─ 0.006 Timestamp.from_astropy  adam_core/time/time.py:198
#    │  │  │  └─ 0.006 Timestamp._from_astropy_scalar  adam_core/time/time.py:240
#    │  │  │     └─ 0.003 Timestamp.from_kwargs  quivr/tables.py:251
#    │  │  │        └─ 0.002 Timestamp._build_arrow_table  quivr/tables.py:341
#    │  │  └─ 0.003 [self]  NEOfaster.py
#    │  └─ 0.002 observables_to_geocentric_state  NEOfaster.py:120
#    │     └─ 0.002 outer  numpy/_core/numeric.py:896
#    └─ 0.006 get_earth_and_observer  NEOfaster.py:146
#       └─ 0.004 EarthLocation.get_gcrs  astropy/coordinates/earth.py:717
#             [2 frames hidden]  astropy
